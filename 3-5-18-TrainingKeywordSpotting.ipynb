# %% [markdown]
# # Training Keyword Spotting
# This notebook builds on the Colab in which we used the pre-trained [micro_speech](https://github.com/tensorflow/tensorflow/tree/master/tensorflow/lite/micro/examples/micro_speech) example.
#
# **It is now time for you to train your own custom keyword spotting model using the Speech Commands dataset!**

# %% [markdown]
# #Setup

# %% [markdown]
# ### Import packages
# Clone the TensorFlow Github Repository, which contains the relevant code required to run this assignment.

# %%
# %tensorflow_version 1.x
import tensorflow as tf
# !wget https://github.com/tensorflow/tensorflow/archive/v2.4.1.zip
# !unzip v2.4.1.zip &> 0
# !mv tensorflow-2.4.1/ tensorflow/
import sys
# We add this path so we can import the speech processing modules.
sys.path.append("/content/tensorflow/tensorflow/examples/speech_commands/")
import input_data
import models
import numpy as np
import pickle
# Out:
# TensorFlow 1.x selected.
# --2021-05-25 20:15:20--  https://github.com/tensorflow/tensorflow/archive/v2.4.1.zip
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/tensorflow/tensorflow/zip/v2.4.1 [following]
# --2021-05-25 20:15:20--  https://codeload.github.com/tensorflow/tensorflow/zip/v2.4.1
# Resolving codeload.github.com (codeload.github.com)... 192.30.255.120
# Connecting to codeload.github.com (codeload.github.com)|192.30.255.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘v2.4.1.zip’
#
# v2.4.1.zip              [  <=>               ]  66.13M  10.8MB/s    in 7.3s
#
# 2021-05-25 20:15:27 (9.11 MB/s) - ‘v2.4.1.zip’ saved [69346072]

# %% [markdown]
# ### Configure Your Model!
# Select your keywords and model settings with which to train!
#
# **This is where you need to make choices and input data!**
#
# ```WANTED_WORDS``` = A comma-delimited string of the words you want to train for (e.g., "yes,no"). All the other words you do not select will be used to train an "unknown" label so that the model does not just recognize speech but your specific words. Audio data with no spoken words will be used to train a "silence" label. We suggest picking 2-4 words for best results.
#
# Options for target words are (PICK FROM THIS LIST FOR BEST RESULTS): "one", "two", "three", "four", "five", "six", "seven", "eight", "nine",  "yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go", “backward”, “forward”, “follow”, “learn”,
#
# Additional words that will be used to help train the "unkown" label are: "bed", "bird", "cat", "dog", "happy", "house", "marvin", "sheila", "tree", "wow"

# %%
WANTED_WORDS = "stop,go,left,right"

# %% [markdown]
# The number of training steps and learning rates can be specified as comma-separated strings to define the amount/rate at each stage. For example, ```TRAINING_STEPS="12000,3000"``` and ```LEARNING_RATE="0.001,0.0001"``` will run 12,000 training steps with a rate of 0.001 followed by 3,000 final steps with a learning rate of 0.0001. These are good default values to work off of when you choose your values as the course staff has gotten this to work well with those values in the past!

# %%
TRAINING_STEPS = "10000,3000,2000"
LEARNING_RATE = "0.0016,0.0004,0.0001"

# %% [markdown]
# We suggest you leave the ```MODEL_ARCHITECTURE``` as tiny_conv the first time but if you would like to do this again and explore additional models some options are: ```single_fc, conv, low_latency_conv, low_latency_svdf, tiny_embedding_conv```

# %%
MODEL_ARCHITECTURE = 'tiny_conv'

# %%
# Calculate the total number of steps, which is used to identify the checkpoint
# file name.
TOTAL_STEPS = str(sum(map(lambda string: int(string), TRAINING_STEPS.split(","))))

# Print the configuration to confirm it
print("Training these words: %s" % WANTED_WORDS)
print("Training steps in each stage: %s" % TRAINING_STEPS)
print("Learning rate in each stage: %s" % LEARNING_RATE)
print("Total number of training steps: %s" % TOTAL_STEPS)
# Out:
# Training these words: stop,go,left,right
# Training steps in each stage: 10000,3000,2000
# Learning rate in each stage: 0.0016,0.0004,0.0001
# Total number of training steps: 15000

# %% [markdown]
# **DO NOT MODIFY** the following constants as they include filepaths used in this notebook and data that is shared during training and inference.

# %%
# Calculate the percentage of 'silence' and 'unknown' training samples required
# to ensure that we have equal number of samples for each label.
number_of_labels = WANTED_WORDS.count(',') + 1
number_of_total_labels = number_of_labels + 2 # for 'silence' and 'unknown' label
equal_percentage_of_training_samples = int(100.0/(number_of_total_labels))
SILENT_PERCENTAGE = equal_percentage_of_training_samples
UNKNOWN_PERCENTAGE = equal_percentage_of_training_samples

# Constants which are shared during training and inference
PREPROCESS = 'micro'
WINDOW_STRIDE = 20

# Constants used during training only
VERBOSITY = 'DEBUG'
EVAL_STEP_INTERVAL = '1000'
SAVE_STEP_INTERVAL = '1000'

# Constants for training directories and filepaths
DATASET_DIR =  'dataset/'
LOGS_DIR = 'logs/'
TRAIN_DIR = 'train/' # for training checkpoints and other files.

# Constants for inference directories and filepaths
import os
MODELS_DIR = 'models'
if not os.path.exists(MODELS_DIR):
  os.mkdir(MODELS_DIR)
MODEL_TF = os.path.join(MODELS_DIR, 'model.pb')
MODEL_TFLITE = os.path.join(MODELS_DIR, 'model.tflite')
FLOAT_MODEL_TFLITE = os.path.join(MODELS_DIR, 'float_model.tflite')
MODEL_TFLITE_MICRO = os.path.join(MODELS_DIR, 'model.cc')
SAVED_MODEL = os.path.join(MODELS_DIR, 'saved_model')

# Constants for Quantization
QUANT_INPUT_MIN = 0.0
QUANT_INPUT_MAX = 26.0
QUANT_INPUT_RANGE = QUANT_INPUT_MAX - QUANT_INPUT_MIN

# Constants for audio process during Quantization and Evaluation
SAMPLE_RATE = 16000
CLIP_DURATION_MS = 1000
WINDOW_SIZE_MS = 30.0
FEATURE_BIN_COUNT = 40
BACKGROUND_FREQUENCY = 0.8
BACKGROUND_VOLUME_RANGE = 0.1
TIME_SHIFT_MS = 100.0

# URL for the dataset and train/val/test split
DATA_URL = 'https://storage.googleapis.com/download.tensorflow.org/data/speech_commands_v0.02.tar.gz'
VALIDATION_PERCENTAGE = 10
TESTING_PERCENTAGE = 10

# %%
# Calculate the correct flattened input data shape for later use in model conversion
# since the model takes a flattened version of the spectrogram. The shape is number of 
# overlapping windows times the number of frequency bins. For the default settings we have
# 40 bins (as set above) times 49 windows (as calculated below) so the shape is (1,1960)
def window_counter(total_samples, window_size, stride):
  '''helper function to count the number of full-length overlapping windows'''
  window_count = 0
  sample_index = 0
  while True:
    window = range(sample_index,sample_index+stride)
    if window.stop < total_samples:
      window_count += 1
    else:
      break
    
    sample_index += stride
  return window_count

OVERLAPPING_WINDOWS = window_counter(CLIP_DURATION_MS, int(WINDOW_SIZE_MS), WINDOW_STRIDE)
FLATTENED_SPECTROGRAM_SHAPE = (1, OVERLAPPING_WINDOWS * FEATURE_BIN_COUNT)

# %% [markdown]
# # Train the model

# %% [markdown]
# ### Load in TensorBoard to visulaize the training process.
#
# As training progresses you should see the training status show up in the Tensorboard area. If this works it is very helpful for analyzing your training progress. Unfortunately, the staff has found that it sometimes doesn't start showing data for a while (~15 minutes) and sometimes doesn't show data until training completes (and instead shows ```No dashboards are active for the current data set```.). If it is working and then stops updating look to the top of the cell and click reconnect.

# %%
# %load_ext tensorboard
# %tensorboard --logdir {LOGS_DIR}

# %% [markdown]
# ### Launch Training
#
# **ARE YOU USING A GPU INSTANCE!?!?!**
# Make sure to check ```runtime->change runtime type``` as a GPU runtime will take ~2 hours to complete training whereas a CPU runtime with take ~10 hours!
#
# **Importantly, every hour or so you should make sure to remind colab you are still there by clicking around in a cell or clicking reconnect on the tensorboard cell (after 90 minutes of no activity Colab may kill the instance)!** But/and beyond that you can absolutely minimize the window and continue with other work.
#
# **If you run training a second time** we suggest restarting your runtime ```runtime->restart runtime``` in order to ensure all caches are cleared. However, do note that doing so will clear all cells and so you will have to run the entire file again.
#
# If you would like to get more information on the training script you can find the source code for the script [here](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/speech_commands/train.py). In short it sets up the optimizer and preprocessor based on all of the flags we pass in!
#
# Finally, by setting the ```VERBOSITY = 'DEBUG'``` above be aware that the training cell will print A LOT of information. Specifically you will get the accuracy and loss at each step as well as a confusion matrix every 1000 steps. We hope that is helpful in case TensorBoard fails to work. If you would like to run with less printouts you can change the setting to ```WARN``` or ```FATAL```. You will find this in the "Configure Your Model!" section.

# %%
# !python tensorflow/tensorflow/examples/speech_commands/train.py \
--data_dir={DATASET_DIR} \
--wanted_words={WANTED_WORDS} \
--silence_percentage={SILENT_PERCENTAGE} \
--unknown_percentage={UNKNOWN_PERCENTAGE} \
--preprocess={PREPROCESS} \
--window_stride={WINDOW_STRIDE} \
--model_architecture={MODEL_ARCHITECTURE} \
--how_many_training_steps={TRAINING_STEPS} \
--learning_rate={LEARNING_RATE} \
--train_dir={TRAIN_DIR} \
--summaries_dir={LOGS_DIR} \
--verbosity={VERBOSITY} \
--eval_step_interval={EVAL_STEP_INTERVAL} \
--save_step_interval={SAVE_STEP_INTERVAL}
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:tensorflow:Step #12540: rate 0.000400, accuracy 81.0%, cross entropy 0.636611
# I0525 21:40:40.602378 140628807952256 train.py:257] Step #12540: rate 0.000400, accuracy 81.0%, cross entropy 0.636611
# DEBUG:tensorflow:Step #12541: rate 0.000400, accuracy 84.0%, cross entropy 0.565196
# I0525 21:40:40.937201 140628807952256 train.py:257] Step #12541: rate 0.000400, accuracy 84.0%, cross entropy 0.565196
# DEBUG:tensorflow:Step #12542: rate 0.000400, accuracy 80.0%, cross entropy 0.582532
# I0525 21:40:41.282478 140628807952256 train.py:257] Step #12542: rate 0.000400, accuracy 80.0%, cross entropy 0.582532
# DEBUG:tensorflow:Step #12543: rate 0.000400, accuracy 80.0%, cross entropy 0.705555
# I0525 21:40:41.625876 140628807952256 train.py:257] Step #12543: rate 0.000400, accuracy 80.0%, cross entropy 0.705555
# DEBUG:tensorflow:Step #12544: rate 0.000400, accuracy 81.0%, cross entropy 0.525114
# I0525 21:40:41.966006 140628807952256 train.py:257] Step #12544: rate 0.000400, accuracy 81.0%, cross entropy 0.525114
# DEBUG:tensorflow:Step #12545: rate 0.000400, accuracy 88.0%, cross entropy 0.394341
# I0525 21:40:42.320051 140628807952256 train.py:257] Step #12545: rate 0.000400, accuracy 88.0%, cross entropy 0.394341
# DEBUG:tensorflow:Step #12546: rate 0.000400, accuracy 89.0%, cross entropy 0.394682
# I0525 21:40:42.704624 140628807952256 train.py:257] Step #12546: rate 0.000400, accuracy 89.0%, cross entropy 0.394682
# DEBUG:tensorflow:Step #12547: rate 0.000400, accuracy 86.0%, cross entropy 0.535034
# I0525 21:40:43.202819 140628807952256 train.py:257] Step #12547: rate 0.000400, accuracy 86.0%, cross entropy 0.535034
# DEBUG:tensorflow:Step #12548: rate 0.000400, accuracy 79.0%, cross entropy 0.635429
# I0525 21:40:43.539270 140628807952256 train.py:257] Step #12548: rate 0.000400, accuracy 79.0%, cross entropy 0.635429
# DEBUG:tensorflow:Step #12549: rate 0.000400, accuracy 83.0%, cross entropy 0.523090
# I0525 21:40:43.883918 140628807952256 train.py:257] Step #12549: rate 0.000400, accuracy 83.0%, cross entropy 0.523090
# DEBUG:tensorflow:Step #12550: rate 0.000400, accuracy 81.0%, cross entropy 0.552687
# I0525 21:40:44.234820 140628807952256 train.py:257] Step #12550: rate 0.000400, accuracy 81.0%, cross entropy 0.552687
# DEBUG:tensorflow:Step #12551: rate 0.000400, accuracy 80.0%, cross entropy 0.544330
# I0525 21:40:44.585679 140628807952256 train.py:257] Step #12551: rate 0.000400, accuracy 80.0%, cross entropy 0.544330
# DEBUG:tensorflow:Step #12552: rate 0.000400, accuracy 85.0%, cross entropy 0.404664
# I0525 21:40:44.922954 140628807952256 train.py:257] Step #12552: rate 0.000400, accuracy 85.0%, cross entropy 0.404664
# DEBUG:tensorflow:Step #12553: rate 0.000400, accuracy 82.0%, cross entropy 0.524084
# I0525 21:40:45.266041 140628807952256 train.py:257] Step #12553: rate 0.000400, accuracy 82.0%, cross entropy 0.524084
# DEBUG:tensorflow:Step #12554: rate 0.000400, accuracy 84.0%, cross entropy 0.475877
# I0525 21:40:45.602944 140628807952256 train.py:257] Step #12554: rate 0.000400, accuracy 84.0%, cross entropy 0.475877
# DEBUG:tensorflow:Step #12555: rate 0.000400, accuracy 77.0%, cross entropy 0.681380
# I0525 21:40:45.943757 140628807952256 train.py:257] Step #12555: rate 0.000400, accuracy 77.0%, cross entropy 0.681380
# DEBUG:tensorflow:Step #12556: rate 0.000400, accuracy 81.0%, cross entropy 0.550553
# I0525 21:40:46.284070 140628807952256 train.py:257] Step #12556: rate 0.000400, accuracy 81.0%, cross entropy 0.550553
# DEBUG:tensorflow:Step #12557: rate 0.000400, accuracy 79.0%, cross entropy 0.584988
# I0525 21:40:46.628304 140628807952256 train.py:257] Step #12557: rate 0.000400, accuracy 79.0%, cross entropy 0.584988
# DEBUG:tensorflow:Step #12558: rate 0.000400, accuracy 88.0%, cross entropy 0.374244
# I0525 21:40:46.967293 140628807952256 train.py:257] Step #12558: rate 0.000400, accuracy 88.0%, cross entropy 0.374244
# DEBUG:tensorflow:Step #12559: rate 0.000400, accuracy 89.0%, cross entropy 0.362398
# I0525 21:40:47.312895 140628807952256 train.py:257] Step #12559: rate 0.000400, accuracy 89.0%, cross entropy 0.362398
# DEBUG:tensorflow:Step #12560: rate 0.000400, accuracy 83.0%, cross entropy 0.490419
# I0525 21:40:47.654520 140628807952256 train.py:257] Step #12560: rate 0.000400, accuracy 83.0%, cross entropy 0.490419
# DEBUG:tensorflow:Step #12561: rate 0.000400, accuracy 83.0%, cross entropy 0.416198
# I0525 21:40:47.999500 140628807952256 train.py:257] Step #12561: rate 0.000400, accuracy 83.0%, cross entropy 0.416198
# DEBUG:tensorflow:Step #12562: rate 0.000400, accuracy 87.0%, cross entropy 0.455075
# I0525 21:40:48.514350 140628807952256 train.py:257] Step #12562: rate 0.000400, accuracy 87.0%, cross entropy 0.455075
# DEBUG:tensorflow:Step #12563: rate 0.000400, accuracy 82.0%, cross entropy 0.580981
# I0525 21:40:48.906319 140628807952256 train.py:257] Step #12563: rate 0.000400, accuracy 82.0%, cross entropy 0.580981
# DEBUG:tensorflow:Step #12564: rate 0.000400, accuracy 84.0%, cross entropy 0.461059
# I0525 21:40:49.256463 140628807952256 train.py:257] Step #12564: rate 0.000400, accuracy 84.0%, cross entropy 0.461059
# DEBUG:tensorflow:Step #12565: rate 0.000400, accuracy 87.0%, cross entropy 0.444457
# I0525 21:40:49.590902 140628807952256 train.py:257] Step #12565: rate 0.000400, accuracy 87.0%, cross entropy 0.444457
# DEBUG:tensorflow:Step #12566: rate 0.000400, accuracy 86.0%, cross entropy 0.403102
# I0525 21:40:49.925603 140628807952256 train.py:257] Step #12566: rate 0.000400, accuracy 86.0%, cross entropy 0.403102
# DEBUG:tensorflow:Step #12567: rate 0.000400, accuracy 82.0%, cross entropy 0.500183
# I0525 21:40:50.269533 140628807952256 train.py:257] Step #12567: rate 0.000400, accuracy 82.0%, cross entropy 0.500183
# DEBUG:tensorflow:Step #12568: rate 0.000400, accuracy 86.0%, cross entropy 0.561726
# I0525 21:40:50.605274 140628807952256 train.py:257] Step #12568: rate 0.000400, accuracy 86.0%, cross entropy 0.561726
# DEBUG:tensorflow:Step #12569: rate 0.000400, accuracy 86.0%, cross entropy 0.426062
# I0525 21:40:50.933328 140628807952256 train.py:257] Step #12569: rate 0.000400, accuracy 86.0%, cross entropy 0.426062
# DEBUG:tensorflow:Step #12570: rate 0.000400, accuracy 82.0%, cross entropy 0.484886
# I0525 21:40:51.283499 140628807952256 train.py:257] Step #12570: rate 0.000400, accuracy 82.0%, cross entropy 0.484886
# DEBUG:tensorflow:Step #12571: rate 0.000400, accuracy 77.0%, cross entropy 0.621605
# I0525 21:40:51.617503 140628807952256 train.py:257] Step #12571: rate 0.000400, accuracy 77.0%, cross entropy 0.621605
# DEBUG:tensorflow:Step #12572: rate 0.000400, accuracy 81.0%, cross entropy 0.592766
# I0525 21:40:51.960572 140628807952256 train.py:257] Step #12572: rate 0.000400, accuracy 81.0%, cross entropy 0.592766
# DEBUG:tensorflow:Step #12573: rate 0.000400, accuracy 82.0%, cross entropy 0.496243
# I0525 21:40:52.307486 140628807952256 train.py:257] Step #12573: rate 0.000400, accuracy 82.0%, cross entropy 0.496243
# DEBUG:tensorflow:Step #12574: rate 0.000400, accuracy 88.0%, cross entropy 0.368712
# I0525 21:40:52.643008 140628807952256 train.py:257] Step #12574: rate 0.000400, accuracy 88.0%, cross entropy 0.368712
# DEBUG:tensorflow:Step #12575: rate 0.000400, accuracy 84.0%, cross entropy 0.515290
# I0525 21:40:52.974175 140628807952256 train.py:257] Step #12575: rate 0.000400, accuracy 84.0%, cross entropy 0.515290
# DEBUG:tensorflow:Step #12576: rate 0.000400, accuracy 87.0%, cross entropy 0.406447
# I0525 21:40:53.318284 140628807952256 train.py:257] Step #12576: rate 0.000400, accuracy 87.0%, cross entropy 0.406447
# DEBUG:tensorflow:Step #12577: rate 0.000400, accuracy 78.0%, cross entropy 0.543915
# I0525 21:40:53.654407 140628807952256 train.py:257] Step #12577: rate 0.000400, accuracy 78.0%, cross entropy 0.543915
# DEBUG:tensorflow:Step #12578: rate 0.000400, accuracy 80.0%, cross entropy 0.548410
# I0525 21:40:54.199617 140628807952256 train.py:257] Step #12578: rate 0.000400, accuracy 80.0%, cross entropy 0.548410
# DEBUG:tensorflow:Step #12579: rate 0.000400, accuracy 81.0%, cross entropy 0.547814
# I0525 21:40:54.540540 140628807952256 train.py:257] Step #12579: rate 0.000400, accuracy 81.0%, cross entropy 0.547814
# DEBUG:tensorflow:Step #12580: rate 0.000400, accuracy 83.0%, cross entropy 0.513577
# I0525 21:40:54.870927 140628807952256 train.py:257] Step #12580: rate 0.000400, accuracy 83.0%, cross entropy 0.513577
# DEBUG:tensorflow:Step #12581: rate 0.000400, accuracy 86.0%, cross entropy 0.373258
# I0525 21:40:55.204041 140628807952256 train.py:257] Step #12581: rate 0.000400, accuracy 86.0%, cross entropy 0.373258
# DEBUG:tensorflow:Step #12582: rate 0.000400, accuracy 82.0%, cross entropy 0.461672
# I0525 21:40:55.541450 140628807952256 train.py:257] Step #12582: rate 0.000400, accuracy 82.0%, cross entropy 0.461672
# DEBUG:tensorflow:Step #12583: rate 0.000400, accuracy 88.0%, cross entropy 0.470544
# I0525 21:40:55.872672 140628807952256 train.py:257] Step #12583: rate 0.000400, accuracy 88.0%, cross entropy 0.470544
# DEBUG:tensorflow:Step #12584: rate 0.000400, accuracy 86.0%, cross entropy 0.418954
# I0525 21:40:56.203696 140628807952256 train.py:257] Step #12584: rate 0.000400, accuracy 86.0%, cross entropy 0.418954
# DEBUG:tensorflow:Step #12585: rate 0.000400, accuracy 90.0%, cross entropy 0.411746
# I0525 21:40:56.538753 140628807952256 train.py:257] Step #12585: rate 0.000400, accuracy 90.0%, cross entropy 0.411746
# DEBUG:tensorflow:Step #12586: rate 0.000400, accuracy 84.0%, cross entropy 0.556590
# I0525 21:40:56.869209 140628807952256 train.py:257] Step #12586: rate 0.000400, accuracy 84.0%, cross entropy 0.556590
# DEBUG:tensorflow:Step #12587: rate 0.000400, accuracy 82.0%, cross entropy 0.480644
# I0525 21:40:57.202134 140628807952256 train.py:257] Step #12587: rate 0.000400, accuracy 82.0%, cross entropy 0.480644
# DEBUG:tensorflow:Step #12588: rate 0.000400, accuracy 79.0%, cross entropy 0.614679
# I0525 21:40:57.558537 140628807952256 train.py:257] Step #12588: rate 0.000400, accuracy 79.0%, cross entropy 0.614679
# DEBUG:tensorflow:Step #12589: rate 0.000400, accuracy 79.0%, cross entropy 0.677197
# I0525 21:40:57.894763 140628807952256 train.py:257] Step #12589: rate 0.000400, accuracy 79.0%, cross entropy 0.677197
# DEBUG:tensorflow:Step #12590: rate 0.000400, accuracy 79.0%, cross entropy 0.714116
# I0525 21:40:58.224928 140628807952256 train.py:257] Step #12590: rate 0.000400, accuracy 79.0%, cross entropy 0.714116
# DEBUG:tensorflow:Step #12591: rate 0.000400, accuracy 77.0%, cross entropy 0.617193
# I0525 21:40:58.570253 140628807952256 train.py:257] Step #12591: rate 0.000400, accuracy 77.0%, cross entropy 0.617193
# DEBUG:tensorflow:Step #12592: rate 0.000400, accuracy 83.0%, cross entropy 0.455855
# I0525 21:40:58.933179 140628807952256 train.py:257] Step #12592: rate 0.000400, accuracy 83.0%, cross entropy 0.455855
# DEBUG:tensorflow:Step #12593: rate 0.000400, accuracy 82.0%, cross entropy 0.611090
# I0525 21:40:59.307106 140628807952256 train.py:257] Step #12593: rate 0.000400, accuracy 82.0%, cross entropy 0.611090
# DEBUG:tensorflow:Step #12594: rate 0.000400, accuracy 78.0%, cross entropy 0.645715
# I0525 21:40:59.791039 140628807952256 train.py:257] Step #12594: rate 0.000400, accuracy 78.0%, cross entropy 0.645715
# DEBUG:tensorflow:Step #12595: rate 0.000400, accuracy 83.0%, cross entropy 0.528945
# I0525 21:41:00.123705 140628807952256 train.py:257] Step #12595: rate 0.000400, accuracy 83.0%, cross entropy 0.528945
# DEBUG:tensorflow:Step #12596: rate 0.000400, accuracy 82.0%, cross entropy 0.561347
# I0525 21:41:00.454894 140628807952256 train.py:257] Step #12596: rate 0.000400, accuracy 82.0%, cross entropy 0.561347
# DEBUG:tensorflow:Step #12597: rate 0.000400, accuracy 79.0%, cross entropy 0.467694
# I0525 21:41:00.794212 140628807952256 train.py:257] Step #12597: rate 0.000400, accuracy 79.0%, cross entropy 0.467694
# DEBUG:tensorflow:Step #12598: rate 0.000400, accuracy 87.0%, cross entropy 0.403238
# I0525 21:41:01.127427 140628807952256 train.py:257] Step #12598: rate 0.000400, accuracy 87.0%, cross entropy 0.403238
# DEBUG:tensorflow:Step #12599: rate 0.000400, accuracy 76.0%, cross entropy 0.728092
# I0525 21:41:01.461431 140628807952256 train.py:257] Step #12599: rate 0.000400, accuracy 76.0%, cross entropy 0.728092
# DEBUG:tensorflow:Step #12600: rate 0.000400, accuracy 86.0%, cross entropy 0.371172
# I0525 21:41:01.793587 140628807952256 train.py:257] Step #12600: rate 0.000400, accuracy 86.0%, cross entropy 0.371172
# DEBUG:tensorflow:Step #12601: rate 0.000400, accuracy 75.0%, cross entropy 0.548098
# I0525 21:41:02.127792 140628807952256 train.py:257] Step #12601: rate 0.000400, accuracy 75.0%, cross entropy 0.548098
# DEBUG:tensorflow:Step #12602: rate 0.000400, accuracy 85.0%, cross entropy 0.448869
# I0525 21:41:02.467671 140628807952256 train.py:257] Step #12602: rate 0.000400, accuracy 85.0%, cross entropy 0.448869
# DEBUG:tensorflow:Step #12603: rate 0.000400, accuracy 84.0%, cross entropy 0.485236
# I0525 21:41:02.809942 140628807952256 train.py:257] Step #12603: rate 0.000400, accuracy 84.0%, cross entropy 0.485236
# DEBUG:tensorflow:Step #12604: rate 0.000400, accuracy 80.0%, cross entropy 0.546230
# I0525 21:41:03.141551 140628807952256 train.py:257] Step #12604: rate 0.000400, accuracy 80.0%, cross entropy 0.546230
# DEBUG:tensorflow:Step #12605: rate 0.000400, accuracy 88.0%, cross entropy 0.356098
# I0525 21:41:03.482443 140628807952256 train.py:257] Step #12605: rate 0.000400, accuracy 88.0%, cross entropy 0.356098
# DEBUG:tensorflow:Step #12606: rate 0.000400, accuracy 72.0%, cross entropy 0.819829
# I0525 21:41:03.817590 140628807952256 train.py:257] Step #12606: rate 0.000400, accuracy 72.0%, cross entropy 0.819829
# DEBUG:tensorflow:Step #12607: rate 0.000400, accuracy 78.0%, cross entropy 0.644397
# I0525 21:41:04.185191 140628807952256 train.py:257] Step #12607: rate 0.000400, accuracy 78.0%, cross entropy 0.644397
# DEBUG:tensorflow:Step #12608: rate 0.000400, accuracy 82.0%, cross entropy 0.488007
# I0525 21:41:04.534288 140628807952256 train.py:257] Step #12608: rate 0.000400, accuracy 82.0%, cross entropy 0.488007
# DEBUG:tensorflow:Step #12609: rate 0.000400, accuracy 81.0%, cross entropy 0.595254
# I0525 21:41:04.932534 140628807952256 train.py:257] Step #12609: rate 0.000400, accuracy 81.0%, cross entropy 0.595254
# DEBUG:tensorflow:Step #12610: rate 0.000400, accuracy 78.0%, cross entropy 0.700202
# I0525 21:41:05.388051 140628807952256 train.py:257] Step #12610: rate 0.000400, accuracy 78.0%, cross entropy 0.700202
# DEBUG:tensorflow:Step #12611: rate 0.000400, accuracy 77.0%, cross entropy 0.729708
# I0525 21:41:05.721293 140628807952256 train.py:257] Step #12611: rate 0.000400, accuracy 77.0%, cross entropy 0.729708
# DEBUG:tensorflow:Step #12612: rate 0.000400, accuracy 80.0%, cross entropy 0.607126
# I0525 21:41:06.061109 140628807952256 train.py:257] Step #12612: rate 0.000400, accuracy 80.0%, cross entropy 0.607126
# DEBUG:tensorflow:Step #12613: rate 0.000400, accuracy 84.0%, cross entropy 0.468367
# I0525 21:41:06.408120 140628807952256 train.py:257] Step #12613: rate 0.000400, accuracy 84.0%, cross entropy 0.468367
# DEBUG:tensorflow:Step #12614: rate 0.000400, accuracy 86.0%, cross entropy 0.445598
# I0525 21:41:06.740673 140628807952256 train.py:257] Step #12614: rate 0.000400, accuracy 86.0%, cross entropy 0.445598
# DEBUG:tensorflow:Step #12615: rate 0.000400, accuracy 80.0%, cross entropy 0.665942
# I0525 21:41:07.077572 140628807952256 train.py:257] Step #12615: rate 0.000400, accuracy 80.0%, cross entropy 0.665942
# DEBUG:tensorflow:Step #12616: rate 0.000400, accuracy 84.0%, cross entropy 0.511623
# I0525 21:41:07.420710 140628807952256 train.py:257] Step #12616: rate 0.000400, accuracy 84.0%, cross entropy 0.511623
# DEBUG:tensorflow:Step #12617: rate 0.000400, accuracy 77.0%, cross entropy 0.651351
# I0525 21:41:07.748730 140628807952256 train.py:257] Step #12617: rate 0.000400, accuracy 77.0%, cross entropy 0.651351
# DEBUG:tensorflow:Step #12618: rate 0.000400, accuracy 75.0%, cross entropy 0.635059
# I0525 21:41:08.089486 140628807952256 train.py:257] Step #12618: rate 0.000400, accuracy 75.0%, cross entropy 0.635059
# DEBUG:tensorflow:Step #12619: rate 0.000400, accuracy 80.0%, cross entropy 0.490472
# I0525 21:41:08.432152 140628807952256 train.py:257] Step #12619: rate 0.000400, accuracy 80.0%, cross entropy 0.490472
# DEBUG:tensorflow:Step #12620: rate 0.000400, accuracy 83.0%, cross entropy 0.497680
# I0525 21:41:08.764475 140628807952256 train.py:257] Step #12620: rate 0.000400, accuracy 83.0%, cross entropy 0.497680
# DEBUG:tensorflow:Step #12621: rate 0.000400, accuracy 80.0%, cross entropy 0.559240
# I0525 21:41:09.101914 140628807952256 train.py:257] Step #12621: rate 0.000400, accuracy 80.0%, cross entropy 0.559240
# DEBUG:tensorflow:Step #12622: rate 0.000400, accuracy 77.0%, cross entropy 0.576749
# I0525 21:41:09.481884 140628807952256 train.py:257] Step #12622: rate 0.000400, accuracy 77.0%, cross entropy 0.576749
# DEBUG:tensorflow:Step #12623: rate 0.000400, accuracy 88.0%, cross entropy 0.423623
# I0525 21:41:09.840377 140628807952256 train.py:257] Step #12623: rate 0.000400, accuracy 88.0%, cross entropy 0.423623
# DEBUG:tensorflow:Step #12624: rate 0.000400, accuracy 79.0%, cross entropy 0.593133
# I0525 21:41:10.176595 140628807952256 train.py:257] Step #12624: rate 0.000400, accuracy 79.0%, cross entropy 0.593133
# DEBUG:tensorflow:Step #12625: rate 0.000400, accuracy 82.0%, cross entropy 0.523081
# I0525 21:41:10.633570 140628807952256 train.py:257] Step #12625: rate 0.000400, accuracy 82.0%, cross entropy 0.523081
# DEBUG:tensorflow:Step #12626: rate 0.000400, accuracy 81.0%, cross entropy 0.569943
# I0525 21:41:11.046659 140628807952256 train.py:257] Step #12626: rate 0.000400, accuracy 81.0%, cross entropy 0.569943
# DEBUG:tensorflow:Step #12627: rate 0.000400, accuracy 80.0%, cross entropy 0.469302
# I0525 21:41:11.380622 140628807952256 train.py:257] Step #12627: rate 0.000400, accuracy 80.0%, cross entropy 0.469302
# DEBUG:tensorflow:Step #12628: rate 0.000400, accuracy 82.0%, cross entropy 0.533520
# I0525 21:41:11.726811 140628807952256 train.py:257] Step #12628: rate 0.000400, accuracy 82.0%, cross entropy 0.533520
# DEBUG:tensorflow:Step #12629: rate 0.000400, accuracy 87.0%, cross entropy 0.458642
# I0525 21:41:12.059283 140628807952256 train.py:257] Step #12629: rate 0.000400, accuracy 87.0%, cross entropy 0.458642
# DEBUG:tensorflow:Step #12630: rate 0.000400, accuracy 75.0%, cross entropy 0.662861
# I0525 21:41:12.389650 140628807952256 train.py:257] Step #12630: rate 0.000400, accuracy 75.0%, cross entropy 0.662861
# DEBUG:tensorflow:Step #12631: rate 0.000400, accuracy 78.0%, cross entropy 0.582857
# I0525 21:41:12.736592 140628807952256 train.py:257] Step #12631: rate 0.000400, accuracy 78.0%, cross entropy 0.582857
# DEBUG:tensorflow:Step #12632: rate 0.000400, accuracy 81.0%, cross entropy 0.502373
# I0525 21:41:13.072581 140628807952256 train.py:257] Step #12632: rate 0.000400, accuracy 81.0%, cross entropy 0.502373
# DEBUG:tensorflow:Step #12633: rate 0.000400, accuracy 83.0%, cross entropy 0.575662
# I0525 21:41:13.409594 140628807952256 train.py:257] Step #12633: rate 0.000400, accuracy 83.0%, cross entropy 0.575662
# DEBUG:tensorflow:Step #12634: rate 0.000400, accuracy 84.0%, cross entropy 0.464478
# I0525 21:41:13.758718 140628807952256 train.py:257] Step #12634: rate 0.000400, accuracy 84.0%, cross entropy 0.464478
# DEBUG:tensorflow:Step #12635: rate 0.000400, accuracy 86.0%, cross entropy 0.437409
# I0525 21:41:14.097670 140628807952256 train.py:257] Step #12635: rate 0.000400, accuracy 86.0%, cross entropy 0.437409
# DEBUG:tensorflow:Step #12636: rate 0.000400, accuracy 85.0%, cross entropy 0.464873
# I0525 21:41:14.437807 140628807952256 train.py:257] Step #12636: rate 0.000400, accuracy 85.0%, cross entropy 0.464873
# DEBUG:tensorflow:Step #12637: rate 0.000400, accuracy 77.0%, cross entropy 0.584047
# I0525 21:41:14.808066 140628807952256 train.py:257] Step #12637: rate 0.000400, accuracy 77.0%, cross entropy 0.584047
# DEBUG:tensorflow:Step #12638: rate 0.000400, accuracy 73.0%, cross entropy 0.811447
# I0525 21:41:15.139184 140628807952256 train.py:257] Step #12638: rate 0.000400, accuracy 73.0%, cross entropy 0.811447
# DEBUG:tensorflow:Step #12639: rate 0.000400, accuracy 85.0%, cross entropy 0.352507
# I0525 21:41:15.471177 140628807952256 train.py:257] Step #12639: rate 0.000400, accuracy 85.0%, cross entropy 0.352507
# DEBUG:tensorflow:Step #12640: rate 0.000400, accuracy 76.0%, cross entropy 0.566899
# I0525 21:41:15.813611 140628807952256 train.py:257] Step #12640: rate 0.000400, accuracy 76.0%, cross entropy 0.566899
# DEBUG:tensorflow:Step #12641: rate 0.000400, accuracy 80.0%, cross entropy 0.708534
# I0525 21:41:16.273109 140628807952256 train.py:257] Step #12641: rate 0.000400, accuracy 80.0%, cross entropy 0.708534
# DEBUG:tensorflow:Step #12642: rate 0.000400, accuracy 78.0%, cross entropy 0.619414
# I0525 21:41:16.671312 140628807952256 train.py:257] Step #12642: rate 0.000400, accuracy 78.0%, cross entropy 0.619414
# DEBUG:tensorflow:Step #12643: rate 0.000400, accuracy 78.0%, cross entropy 0.572409
# I0525 21:41:17.004901 140628807952256 train.py:257] Step #12643: rate 0.000400, accuracy 78.0%, cross entropy 0.572409
# DEBUG:tensorflow:Step #12644: rate 0.000400, accuracy 80.0%, cross entropy 0.743550
# I0525 21:41:17.338244 140628807952256 train.py:257] Step #12644: rate 0.000400, accuracy 80.0%, cross entropy 0.743550
# DEBUG:tensorflow:Step #12645: rate 0.000400, accuracy 82.0%, cross entropy 0.614111
# I0525 21:41:17.691048 140628807952256 train.py:257] Step #12645: rate 0.000400, accuracy 82.0%, cross entropy 0.614111
# DEBUG:tensorflow:Step #12646: rate 0.000400, accuracy 75.0%, cross entropy 0.602637
# I0525 21:41:18.018069 140628807952256 train.py:257] Step #12646: rate 0.000400, accuracy 75.0%, cross entropy 0.602637
# DEBUG:tensorflow:Step #12647: rate 0.000400, accuracy 84.0%, cross entropy 0.468276
# I0525 21:41:18.351532 140628807952256 train.py:257] Step #12647: rate 0.000400, accuracy 84.0%, cross entropy 0.468276
# DEBUG:tensorflow:Step #12648: rate 0.000400, accuracy 81.0%, cross entropy 0.503349
# I0525 21:41:18.698553 140628807952256 train.py:257] Step #12648: rate 0.000400, accuracy 81.0%, cross entropy 0.503349
# DEBUG:tensorflow:Step #12649: rate 0.000400, accuracy 76.0%, cross entropy 0.614222
# I0525 21:41:19.036396 140628807952256 train.py:257] Step #12649: rate 0.000400, accuracy 76.0%, cross entropy 0.614222
# DEBUG:tensorflow:Step #12650: rate 0.000400, accuracy 83.0%, cross entropy 0.417667
# I0525 21:41:19.379395 140628807952256 train.py:257] Step #12650: rate 0.000400, accuracy 83.0%, cross entropy 0.417667
# DEBUG:tensorflow:Step #12651: rate 0.000400, accuracy 76.0%, cross entropy 0.586514
# I0525 21:41:19.720928 140628807952256 train.py:257] Step #12651: rate 0.000400, accuracy 76.0%, cross entropy 0.586514
# DEBUG:tensorflow:Step #12652: rate 0.000400, accuracy 84.0%, cross entropy 0.549202
# I0525 21:41:20.086172 140628807952256 train.py:257] Step #12652: rate 0.000400, accuracy 84.0%, cross entropy 0.549202
# DEBUG:tensorflow:Step #12653: rate 0.000400, accuracy 81.0%, cross entropy 0.515724
# I0525 21:41:20.417984 140628807952256 train.py:257] Step #12653: rate 0.000400, accuracy 81.0%, cross entropy 0.515724
# DEBUG:tensorflow:Step #12654: rate 0.000400, accuracy 83.0%, cross entropy 0.524745
# I0525 21:41:20.755479 140628807952256 train.py:257] Step #12654: rate 0.000400, accuracy 83.0%, cross entropy 0.524745
# DEBUG:tensorflow:Step #12655: rate 0.000400, accuracy 87.0%, cross entropy 0.484501
# I0525 21:41:21.103484 140628807952256 train.py:257] Step #12655: rate 0.000400, accuracy 87.0%, cross entropy 0.484501
# DEBUG:tensorflow:Step #12656: rate 0.000400, accuracy 85.0%, cross entropy 0.451871
# I0525 21:41:21.441288 140628807952256 train.py:257] Step #12656: rate 0.000400, accuracy 85.0%, cross entropy 0.451871
# DEBUG:tensorflow:Step #12657: rate 0.000400, accuracy 76.0%, cross entropy 0.598080
# I0525 21:41:21.947675 140628807952256 train.py:257] Step #12657: rate 0.000400, accuracy 76.0%, cross entropy 0.598080
# DEBUG:tensorflow:Step #12658: rate 0.000400, accuracy 88.0%, cross entropy 0.483364
# I0525 21:41:22.314740 140628807952256 train.py:257] Step #12658: rate 0.000400, accuracy 88.0%, cross entropy 0.483364
# DEBUG:tensorflow:Step #12659: rate 0.000400, accuracy 81.0%, cross entropy 0.561148
# I0525 21:41:22.664499 140628807952256 train.py:257] Step #12659: rate 0.000400, accuracy 81.0%, cross entropy 0.561148
# DEBUG:tensorflow:Step #12660: rate 0.000400, accuracy 76.0%, cross entropy 0.684331
# I0525 21:41:23.001577 140628807952256 train.py:257] Step #12660: rate 0.000400, accuracy 76.0%, cross entropy 0.684331
# DEBUG:tensorflow:Step #12661: rate 0.000400, accuracy 81.0%, cross entropy 0.499644
# I0525 21:41:23.339931 140628807952256 train.py:257] Step #12661: rate 0.000400, accuracy 81.0%, cross entropy 0.499644
# DEBUG:tensorflow:Step #12662: rate 0.000400, accuracy 77.0%, cross entropy 0.628090
# I0525 21:41:23.688426 140628807952256 train.py:257] Step #12662: rate 0.000400, accuracy 77.0%, cross entropy 0.628090
# DEBUG:tensorflow:Step #12663: rate 0.000400, accuracy 87.0%, cross entropy 0.420757
# I0525 21:41:24.027897 140628807952256 train.py:257] Step #12663: rate 0.000400, accuracy 87.0%, cross entropy 0.420757
# DEBUG:tensorflow:Step #12664: rate 0.000400, accuracy 76.0%, cross entropy 0.591642
# I0525 21:41:24.370000 140628807952256 train.py:257] Step #12664: rate 0.000400, accuracy 76.0%, cross entropy 0.591642
# DEBUG:tensorflow:Step #12665: rate 0.000400, accuracy 84.0%, cross entropy 0.491006
# I0525 21:41:24.709579 140628807952256 train.py:257] Step #12665: rate 0.000400, accuracy 84.0%, cross entropy 0.491006
# DEBUG:tensorflow:Step #12666: rate 0.000400, accuracy 81.0%, cross entropy 0.606432
# I0525 21:41:25.047564 140628807952256 train.py:257] Step #12666: rate 0.000400, accuracy 81.0%, cross entropy 0.606432
# DEBUG:tensorflow:Step #12667: rate 0.000400, accuracy 81.0%, cross entropy 0.502189
# I0525 21:41:25.410732 140628807952256 train.py:257] Step #12667: rate 0.000400, accuracy 81.0%, cross entropy 0.502189
# DEBUG:tensorflow:Step #12668: rate 0.000400, accuracy 81.0%, cross entropy 0.577645
# I0525 21:41:25.762791 140628807952256 train.py:257] Step #12668: rate 0.000400, accuracy 81.0%, cross entropy 0.577645
# DEBUG:tensorflow:Step #12669: rate 0.000400, accuracy 73.0%, cross entropy 0.594745
# I0525 21:41:26.109909 140628807952256 train.py:257] Step #12669: rate 0.000400, accuracy 73.0%, cross entropy 0.594745
# DEBUG:tensorflow:Step #12670: rate 0.000400, accuracy 81.0%, cross entropy 0.505866
# I0525 21:41:26.447866 140628807952256 train.py:257] Step #12670: rate 0.000400, accuracy 81.0%, cross entropy 0.505866
# DEBUG:tensorflow:Step #12671: rate 0.000400, accuracy 84.0%, cross entropy 0.633769
# I0525 21:41:26.794312 140628807952256 train.py:257] Step #12671: rate 0.000400, accuracy 84.0%, cross entropy 0.633769
# DEBUG:tensorflow:Step #12672: rate 0.000400, accuracy 83.0%, cross entropy 0.600399
# I0525 21:41:27.163882 140628807952256 train.py:257] Step #12672: rate 0.000400, accuracy 83.0%, cross entropy 0.600399
# DEBUG:tensorflow:Step #12673: rate 0.000400, accuracy 84.0%, cross entropy 0.605856
# I0525 21:41:27.671786 140628807952256 train.py:257] Step #12673: rate 0.000400, accuracy 84.0%, cross entropy 0.605856
# DEBUG:tensorflow:Step #12674: rate 0.000400, accuracy 82.0%, cross entropy 0.489810
# I0525 21:41:28.012479 140628807952256 train.py:257] Step #12674: rate 0.000400, accuracy 82.0%, cross entropy 0.489810
# DEBUG:tensorflow:Step #12675: rate 0.000400, accuracy 82.0%, cross entropy 0.511390
# I0525 21:41:28.346302 140628807952256 train.py:257] Step #12675: rate 0.000400, accuracy 82.0%, cross entropy 0.511390
# DEBUG:tensorflow:Step #12676: rate 0.000400, accuracy 86.0%, cross entropy 0.457807
# I0525 21:41:28.689470 140628807952256 train.py:257] Step #12676: rate 0.000400, accuracy 86.0%, cross entropy 0.457807
# DEBUG:tensorflow:Step #12677: rate 0.000400, accuracy 76.0%, cross entropy 0.587600
# I0525 21:41:29.026509 140628807952256 train.py:257] Step #12677: rate 0.000400, accuracy 76.0%, cross entropy 0.587600
# DEBUG:tensorflow:Step #12678: rate 0.000400, accuracy 87.0%, cross entropy 0.384786
# I0525 21:41:29.358177 140628807952256 train.py:257] Step #12678: rate 0.000400, accuracy 87.0%, cross entropy 0.384786
# DEBUG:tensorflow:Step #12679: rate 0.000400, accuracy 82.0%, cross entropy 0.543257
# I0525 21:41:29.706962 140628807952256 train.py:257] Step #12679: rate 0.000400, accuracy 82.0%, cross entropy 0.543257
# DEBUG:tensorflow:Step #12680: rate 0.000400, accuracy 84.0%, cross entropy 0.590855
# I0525 21:41:30.041061 140628807952256 train.py:257] Step #12680: rate 0.000400, accuracy 84.0%, cross entropy 0.590855
# DEBUG:tensorflow:Step #12681: rate 0.000400, accuracy 83.0%, cross entropy 0.556221
# I0525 21:41:30.374224 140628807952256 train.py:257] Step #12681: rate 0.000400, accuracy 83.0%, cross entropy 0.556221
# DEBUG:tensorflow:Step #12682: rate 0.000400, accuracy 84.0%, cross entropy 0.526031
# I0525 21:41:30.741036 140628807952256 train.py:257] Step #12682: rate 0.000400, accuracy 84.0%, cross entropy 0.526031
# DEBUG:tensorflow:Step #12683: rate 0.000400, accuracy 79.0%, cross entropy 0.616976
# I0525 21:41:31.091015 140628807952256 train.py:257] Step #12683: rate 0.000400, accuracy 79.0%, cross entropy 0.616976
# DEBUG:tensorflow:Step #12684: rate 0.000400, accuracy 81.0%, cross entropy 0.534754
# I0525 21:41:31.433715 140628807952256 train.py:257] Step #12684: rate 0.000400, accuracy 81.0%, cross entropy 0.534754
# DEBUG:tensorflow:Step #12685: rate 0.000400, accuracy 80.0%, cross entropy 0.600913
# I0525 21:41:31.772299 140628807952256 train.py:257] Step #12685: rate 0.000400, accuracy 80.0%, cross entropy 0.600913
# DEBUG:tensorflow:Step #12686: rate 0.000400, accuracy 88.0%, cross entropy 0.496613
# I0525 21:41:32.107060 140628807952256 train.py:257] Step #12686: rate 0.000400, accuracy 88.0%, cross entropy 0.496613
# DEBUG:tensorflow:Step #12687: rate 0.000400, accuracy 79.0%, cross entropy 0.651361
# I0525 21:41:32.437307 140628807952256 train.py:257] Step #12687: rate 0.000400, accuracy 79.0%, cross entropy 0.651361
# DEBUG:tensorflow:Step #12688: rate 0.000400, accuracy 74.0%, cross entropy 0.729722
# I0525 21:41:32.864001 140628807952256 train.py:257] Step #12688: rate 0.000400, accuracy 74.0%, cross entropy 0.729722
# DEBUG:tensorflow:Step #12689: rate 0.000400, accuracy 81.0%, cross entropy 0.632976
# I0525 21:41:33.291822 140628807952256 train.py:257] Step #12689: rate 0.000400, accuracy 81.0%, cross entropy 0.632976
# DEBUG:tensorflow:Step #12690: rate 0.000400, accuracy 84.0%, cross entropy 0.519738
# I0525 21:41:33.625941 140628807952256 train.py:257] Step #12690: rate 0.000400, accuracy 84.0%, cross entropy 0.519738
# DEBUG:tensorflow:Step #12691: rate 0.000400, accuracy 87.0%, cross entropy 0.540434
# I0525 21:41:33.959610 140628807952256 train.py:257] Step #12691: rate 0.000400, accuracy 87.0%, cross entropy 0.540434
# DEBUG:tensorflow:Step #12692: rate 0.000400, accuracy 85.0%, cross entropy 0.443165
# I0525 21:41:34.288882 140628807952256 train.py:257] Step #12692: rate 0.000400, accuracy 85.0%, cross entropy 0.443165
# DEBUG:tensorflow:Step #12693: rate 0.000400, accuracy 76.0%, cross entropy 0.638309
# I0525 21:41:34.627477 140628807952256 train.py:257] Step #12693: rate 0.000400, accuracy 76.0%, cross entropy 0.638309
# DEBUG:tensorflow:Step #12694: rate 0.000400, accuracy 80.0%, cross entropy 0.605304
# I0525 21:41:34.972853 140628807952256 train.py:257] Step #12694: rate 0.000400, accuracy 80.0%, cross entropy 0.605304
# DEBUG:tensorflow:Step #12695: rate 0.000400, accuracy 80.0%, cross entropy 0.539185
# I0525 21:41:35.311588 140628807952256 train.py:257] Step #12695: rate 0.000400, accuracy 80.0%, cross entropy 0.539185
# DEBUG:tensorflow:Step #12696: rate 0.000400, accuracy 79.0%, cross entropy 0.648551
# I0525 21:41:35.653477 140628807952256 train.py:257] Step #12696: rate 0.000400, accuracy 79.0%, cross entropy 0.648551
# DEBUG:tensorflow:Step #12697: rate 0.000400, accuracy 77.0%, cross entropy 0.723004
# I0525 21:41:36.027263 140628807952256 train.py:257] Step #12697: rate 0.000400, accuracy 77.0%, cross entropy 0.723004
# DEBUG:tensorflow:Step #12698: rate 0.000400, accuracy 80.0%, cross entropy 0.644582
# I0525 21:41:36.361936 140628807952256 train.py:257] Step #12698: rate 0.000400, accuracy 80.0%, cross entropy 0.644582
# DEBUG:tensorflow:Step #12699: rate 0.000400, accuracy 84.0%, cross entropy 0.622167
# I0525 21:41:36.686964 140628807952256 train.py:257] Step #12699: rate 0.000400, accuracy 84.0%, cross entropy 0.622167
# DEBUG:tensorflow:Step #12700: rate 0.000400, accuracy 78.0%, cross entropy 0.740665
# I0525 21:41:37.024790 140628807952256 train.py:257] Step #12700: rate 0.000400, accuracy 78.0%, cross entropy 0.740665
# DEBUG:tensorflow:Step #12701: rate 0.000400, accuracy 81.0%, cross entropy 0.615286
# I0525 21:41:37.361528 140628807952256 train.py:257] Step #12701: rate 0.000400, accuracy 81.0%, cross entropy 0.615286
# DEBUG:tensorflow:Step #12702: rate 0.000400, accuracy 85.0%, cross entropy 0.402914
# I0525 21:41:37.690314 140628807952256 train.py:257] Step #12702: rate 0.000400, accuracy 85.0%, cross entropy 0.402914
# DEBUG:tensorflow:Step #12703: rate 0.000400, accuracy 82.0%, cross entropy 0.609453
# I0525 21:41:38.028818 140628807952256 train.py:257] Step #12703: rate 0.000400, accuracy 82.0%, cross entropy 0.609453
# DEBUG:tensorflow:Step #12704: rate 0.000400, accuracy 81.0%, cross entropy 0.562684
# I0525 21:41:38.490935 140628807952256 train.py:257] Step #12704: rate 0.000400, accuracy 81.0%, cross entropy 0.562684
# DEBUG:tensorflow:Step #12705: rate 0.000400, accuracy 82.0%, cross entropy 0.528797
# I0525 21:41:38.892966 140628807952256 train.py:257] Step #12705: rate 0.000400, accuracy 82.0%, cross entropy 0.528797
# DEBUG:tensorflow:Step #12706: rate 0.000400, accuracy 84.0%, cross entropy 0.612206
# I0525 21:41:39.225868 140628807952256 train.py:257] Step #12706: rate 0.000400, accuracy 84.0%, cross entropy 0.612206
# DEBUG:tensorflow:Step #12707: rate 0.000400, accuracy 85.0%, cross entropy 0.503017
# I0525 21:41:39.568116 140628807952256 train.py:257] Step #12707: rate 0.000400, accuracy 85.0%, cross entropy 0.503017
# DEBUG:tensorflow:Step #12708: rate 0.000400, accuracy 82.0%, cross entropy 0.499278
# I0525 21:41:39.916648 140628807952256 train.py:257] Step #12708: rate 0.000400, accuracy 82.0%, cross entropy 0.499278
# DEBUG:tensorflow:Step #12709: rate 0.000400, accuracy 81.0%, cross entropy 0.501219
# I0525 21:41:40.259526 140628807952256 train.py:257] Step #12709: rate 0.000400, accuracy 81.0%, cross entropy 0.501219
# DEBUG:tensorflow:Step #12710: rate 0.000400, accuracy 80.0%, cross entropy 0.577772
# I0525 21:41:40.620830 140628807952256 train.py:257] Step #12710: rate 0.000400, accuracy 80.0%, cross entropy 0.577772
# DEBUG:tensorflow:Step #12711: rate 0.000400, accuracy 86.0%, cross entropy 0.507698
# I0525 21:41:40.964970 140628807952256 train.py:257] Step #12711: rate 0.000400, accuracy 86.0%, cross entropy 0.507698
# DEBUG:tensorflow:Step #12712: rate 0.000400, accuracy 80.0%, cross entropy 0.618214
# I0525 21:41:41.326691 140628807952256 train.py:257] Step #12712: rate 0.000400, accuracy 80.0%, cross entropy 0.618214
# DEBUG:tensorflow:Step #12713: rate 0.000400, accuracy 81.0%, cross entropy 0.658722
# I0525 21:41:41.658940 140628807952256 train.py:257] Step #12713: rate 0.000400, accuracy 81.0%, cross entropy 0.658722
# DEBUG:tensorflow:Step #12714: rate 0.000400, accuracy 81.0%, cross entropy 0.616920
# I0525 21:41:42.007670 140628807952256 train.py:257] Step #12714: rate 0.000400, accuracy 81.0%, cross entropy 0.616920
# DEBUG:tensorflow:Step #12715: rate 0.000400, accuracy 79.0%, cross entropy 0.600209
# I0525 21:41:42.343849 140628807952256 train.py:257] Step #12715: rate 0.000400, accuracy 79.0%, cross entropy 0.600209
# DEBUG:tensorflow:Step #12716: rate 0.000400, accuracy 79.0%, cross entropy 0.639406
# I0525 21:41:42.680479 140628807952256 train.py:257] Step #12716: rate 0.000400, accuracy 79.0%, cross entropy 0.639406
# DEBUG:tensorflow:Step #12717: rate 0.000400, accuracy 83.0%, cross entropy 0.567993
# I0525 21:41:43.019663 140628807952256 train.py:257] Step #12717: rate 0.000400, accuracy 83.0%, cross entropy 0.567993
# DEBUG:tensorflow:Step #12718: rate 0.000400, accuracy 75.0%, cross entropy 0.669782
# I0525 21:41:43.362415 140628807952256 train.py:257] Step #12718: rate 0.000400, accuracy 75.0%, cross entropy 0.669782
# DEBUG:tensorflow:Step #12719: rate 0.000400, accuracy 73.0%, cross entropy 0.619617
# I0525 21:41:43.728480 140628807952256 train.py:257] Step #12719: rate 0.000400, accuracy 73.0%, cross entropy 0.619617
# DEBUG:tensorflow:Step #12720: rate 0.000400, accuracy 78.0%, cross entropy 0.554651
# I0525 21:41:44.233650 140628807952256 train.py:257] Step #12720: rate 0.000400, accuracy 78.0%, cross entropy 0.554651
# DEBUG:tensorflow:Step #12721: rate 0.000400, accuracy 75.0%, cross entropy 0.696613
# I0525 21:41:44.572510 140628807952256 train.py:257] Step #12721: rate 0.000400, accuracy 75.0%, cross entropy 0.696613
# DEBUG:tensorflow:Step #12722: rate 0.000400, accuracy 78.0%, cross entropy 0.541414
# I0525 21:41:44.908647 140628807952256 train.py:257] Step #12722: rate 0.000400, accuracy 78.0%, cross entropy 0.541414
# DEBUG:tensorflow:Step #12723: rate 0.000400, accuracy 70.0%, cross entropy 0.874022
# I0525 21:41:45.242755 140628807952256 train.py:257] Step #12723: rate 0.000400, accuracy 70.0%, cross entropy 0.874022
# DEBUG:tensorflow:Step #12724: rate 0.000400, accuracy 83.0%, cross entropy 0.479774
# I0525 21:41:45.574907 140628807952256 train.py:257] Step #12724: rate 0.000400, accuracy 83.0%, cross entropy 0.479774
# DEBUG:tensorflow:Step #12725: rate 0.000400, accuracy 84.0%, cross entropy 0.470120
# I0525 21:41:45.914773 140628807952256 train.py:257] Step #12725: rate 0.000400, accuracy 84.0%, cross entropy 0.470120
# DEBUG:tensorflow:Step #12726: rate 0.000400, accuracy 78.0%, cross entropy 0.628785
# I0525 21:41:46.251682 140628807952256 train.py:257] Step #12726: rate 0.000400, accuracy 78.0%, cross entropy 0.628785
# DEBUG:tensorflow:Step #12727: rate 0.000400, accuracy 80.0%, cross entropy 0.718590
# I0525 21:41:46.624004 140628807952256 train.py:257] Step #12727: rate 0.000400, accuracy 80.0%, cross entropy 0.718590
# DEBUG:tensorflow:Step #12728: rate 0.000400, accuracy 76.0%, cross entropy 0.687747
# I0525 21:41:46.973405 140628807952256 train.py:257] Step #12728: rate 0.000400, accuracy 76.0%, cross entropy 0.687747
# DEBUG:tensorflow:Step #12729: rate 0.000400, accuracy 85.0%, cross entropy 0.526584
# I0525 21:41:47.313016 140628807952256 train.py:257] Step #12729: rate 0.000400, accuracy 85.0%, cross entropy 0.526584
# DEBUG:tensorflow:Step #12730: rate 0.000400, accuracy 74.0%, cross entropy 0.710478
# I0525 21:41:47.651623 140628807952256 train.py:257] Step #12730: rate 0.000400, accuracy 74.0%, cross entropy 0.710478
# DEBUG:tensorflow:Step #12731: rate 0.000400, accuracy 85.0%, cross entropy 0.536268
# I0525 21:41:47.992467 140628807952256 train.py:257] Step #12731: rate 0.000400, accuracy 85.0%, cross entropy 0.536268
# DEBUG:tensorflow:Step #12732: rate 0.000400, accuracy 69.0%, cross entropy 0.799134
# I0525 21:41:48.323796 140628807952256 train.py:257] Step #12732: rate 0.000400, accuracy 69.0%, cross entropy 0.799134
# DEBUG:tensorflow:Step #12733: rate 0.000400, accuracy 81.0%, cross entropy 0.533158
# I0525 21:41:48.659855 140628807952256 train.py:257] Step #12733: rate 0.000400, accuracy 81.0%, cross entropy 0.533158
# DEBUG:tensorflow:Step #12734: rate 0.000400, accuracy 80.0%, cross entropy 0.559272
# I0525 21:41:49.004582 140628807952256 train.py:257] Step #12734: rate 0.000400, accuracy 80.0%, cross entropy 0.559272
# DEBUG:tensorflow:Step #12735: rate 0.000400, accuracy 75.0%, cross entropy 0.740971
# I0525 21:41:49.447230 140628807952256 train.py:257] Step #12735: rate 0.000400, accuracy 75.0%, cross entropy 0.740971
# DEBUG:tensorflow:Step #12736: rate 0.000400, accuracy 77.0%, cross entropy 0.545669
# I0525 21:41:49.857119 140628807952256 train.py:257] Step #12736: rate 0.000400, accuracy 77.0%, cross entropy 0.545669
# DEBUG:tensorflow:Step #12737: rate 0.000400, accuracy 78.0%, cross entropy 0.557476
# I0525 21:41:50.194774 140628807952256 train.py:257] Step #12737: rate 0.000400, accuracy 78.0%, cross entropy 0.557476
# DEBUG:tensorflow:Step #12738: rate 0.000400, accuracy 85.0%, cross entropy 0.478493
# I0525 21:41:50.523376 140628807952256 train.py:257] Step #12738: rate 0.000400, accuracy 85.0%, cross entropy 0.478493
# DEBUG:tensorflow:Step #12739: rate 0.000400, accuracy 80.0%, cross entropy 0.594530
# I0525 21:41:50.859313 140628807952256 train.py:257] Step #12739: rate 0.000400, accuracy 80.0%, cross entropy 0.594530
# DEBUG:tensorflow:Step #12740: rate 0.000400, accuracy 80.0%, cross entropy 0.614524
# I0525 21:41:51.203259 140628807952256 train.py:257] Step #12740: rate 0.000400, accuracy 80.0%, cross entropy 0.614524
# DEBUG:tensorflow:Step #12741: rate 0.000400, accuracy 75.0%, cross entropy 0.710522
# I0525 21:41:51.536705 140628807952256 train.py:257] Step #12741: rate 0.000400, accuracy 75.0%, cross entropy 0.710522
# DEBUG:tensorflow:Step #12742: rate 0.000400, accuracy 78.0%, cross entropy 0.522272
# I0525 21:41:51.904301 140628807952256 train.py:257] Step #12742: rate 0.000400, accuracy 78.0%, cross entropy 0.522272
# DEBUG:tensorflow:Step #12743: rate 0.000400, accuracy 86.0%, cross entropy 0.497030
# I0525 21:41:52.257785 140628807952256 train.py:257] Step #12743: rate 0.000400, accuracy 86.0%, cross entropy 0.497030
# DEBUG:tensorflow:Step #12744: rate 0.000400, accuracy 80.0%, cross entropy 0.542384
# I0525 21:41:52.598122 140628807952256 train.py:257] Step #12744: rate 0.000400, accuracy 80.0%, cross entropy 0.542384
# DEBUG:tensorflow:Step #12745: rate 0.000400, accuracy 79.0%, cross entropy 0.611643
# I0525 21:41:52.948314 140628807952256 train.py:257] Step #12745: rate 0.000400, accuracy 79.0%, cross entropy 0.611643
# DEBUG:tensorflow:Step #12746: rate 0.000400, accuracy 85.0%, cross entropy 0.421203
# I0525 21:41:53.282622 140628807952256 train.py:257] Step #12746: rate 0.000400, accuracy 85.0%, cross entropy 0.421203
# DEBUG:tensorflow:Step #12747: rate 0.000400, accuracy 81.0%, cross entropy 0.534382
# I0525 21:41:53.625694 140628807952256 train.py:257] Step #12747: rate 0.000400, accuracy 81.0%, cross entropy 0.534382
# DEBUG:tensorflow:Step #12748: rate 0.000400, accuracy 84.0%, cross entropy 0.508783
# I0525 21:41:53.973112 140628807952256 train.py:257] Step #12748: rate 0.000400, accuracy 84.0%, cross entropy 0.508783
# DEBUG:tensorflow:Step #12749: rate 0.000400, accuracy 89.0%, cross entropy 0.392941
# I0525 21:41:54.308212 140628807952256 train.py:257] Step #12749: rate 0.000400, accuracy 89.0%, cross entropy 0.392941
# DEBUG:tensorflow:Step #12750: rate 0.000400, accuracy 78.0%, cross entropy 0.647653
# I0525 21:41:54.646708 140628807952256 train.py:257] Step #12750: rate 0.000400, accuracy 78.0%, cross entropy 0.647653
# DEBUG:tensorflow:Step #12751: rate 0.000400, accuracy 80.0%, cross entropy 0.560478
# I0525 21:41:55.157843 140628807952256 train.py:257] Step #12751: rate 0.000400, accuracy 80.0%, cross entropy 0.560478
# DEBUG:tensorflow:Step #12752: rate 0.000400, accuracy 80.0%, cross entropy 0.581114
# I0525 21:41:55.509168 140628807952256 train.py:257] Step #12752: rate 0.000400, accuracy 80.0%, cross entropy 0.581114
# DEBUG:tensorflow:Step #12753: rate 0.000400, accuracy 90.0%, cross entropy 0.335077
# I0525 21:41:55.842843 140628807952256 train.py:257] Step #12753: rate 0.000400, accuracy 90.0%, cross entropy 0.335077
# DEBUG:tensorflow:Step #12754: rate 0.000400, accuracy 75.0%, cross entropy 0.610517
# I0525 21:41:56.181563 140628807952256 train.py:257] Step #12754: rate 0.000400, accuracy 75.0%, cross entropy 0.610517
# DEBUG:tensorflow:Step #12755: rate 0.000400, accuracy 81.0%, cross entropy 0.566733
# I0525 21:41:56.518309 140628807952256 train.py:257] Step #12755: rate 0.000400, accuracy 81.0%, cross entropy 0.566733
# DEBUG:tensorflow:Step #12756: rate 0.000400, accuracy 80.0%, cross entropy 0.585909
# I0525 21:41:56.854581 140628807952256 train.py:257] Step #12756: rate 0.000400, accuracy 80.0%, cross entropy 0.585909
# DEBUG:tensorflow:Step #12757: rate 0.000400, accuracy 78.0%, cross entropy 0.587208
# I0525 21:41:57.219528 140628807952256 train.py:257] Step #12757: rate 0.000400, accuracy 78.0%, cross entropy 0.587208
# DEBUG:tensorflow:Step #12758: rate 0.000400, accuracy 84.0%, cross entropy 0.514801
# I0525 21:41:57.565178 140628807952256 train.py:257] Step #12758: rate 0.000400, accuracy 84.0%, cross entropy 0.514801
# DEBUG:tensorflow:Step #12759: rate 0.000400, accuracy 81.0%, cross entropy 0.483226
# I0525 21:41:57.913798 140628807952256 train.py:257] Step #12759: rate 0.000400, accuracy 81.0%, cross entropy 0.483226
# DEBUG:tensorflow:Step #12760: rate 0.000400, accuracy 82.0%, cross entropy 0.518693
# I0525 21:41:58.257404 140628807952256 train.py:257] Step #12760: rate 0.000400, accuracy 82.0%, cross entropy 0.518693
# DEBUG:tensorflow:Step #12761: rate 0.000400, accuracy 80.0%, cross entropy 0.571784
# I0525 21:41:58.605261 140628807952256 train.py:257] Step #12761: rate 0.000400, accuracy 80.0%, cross entropy 0.571784
# DEBUG:tensorflow:Step #12762: rate 0.000400, accuracy 79.0%, cross entropy 0.498704
# I0525 21:41:58.956025 140628807952256 train.py:257] Step #12762: rate 0.000400, accuracy 79.0%, cross entropy 0.498704
# DEBUG:tensorflow:Step #12763: rate 0.000400, accuracy 78.0%, cross entropy 0.569853
# I0525 21:41:59.312074 140628807952256 train.py:257] Step #12763: rate 0.000400, accuracy 78.0%, cross entropy 0.569853
# DEBUG:tensorflow:Step #12764: rate 0.000400, accuracy 83.0%, cross entropy 0.521567
# I0525 21:41:59.657674 140628807952256 train.py:257] Step #12764: rate 0.000400, accuracy 83.0%, cross entropy 0.521567
# DEBUG:tensorflow:Step #12765: rate 0.000400, accuracy 81.0%, cross entropy 0.497996
# I0525 21:42:00.002715 140628807952256 train.py:257] Step #12765: rate 0.000400, accuracy 81.0%, cross entropy 0.497996
# DEBUG:tensorflow:Step #12766: rate 0.000400, accuracy 76.0%, cross entropy 0.640746
# I0525 21:42:00.416549 140628807952256 train.py:257] Step #12766: rate 0.000400, accuracy 76.0%, cross entropy 0.640746
# DEBUG:tensorflow:Step #12767: rate 0.000400, accuracy 79.0%, cross entropy 0.737835
# I0525 21:42:00.864866 140628807952256 train.py:257] Step #12767: rate 0.000400, accuracy 79.0%, cross entropy 0.737835
# DEBUG:tensorflow:Step #12768: rate 0.000400, accuracy 79.0%, cross entropy 0.618920
# I0525 21:42:01.212880 140628807952256 train.py:257] Step #12768: rate 0.000400, accuracy 79.0%, cross entropy 0.618920
# DEBUG:tensorflow:Step #12769: rate 0.000400, accuracy 71.0%, cross entropy 0.742010
# I0525 21:42:01.550055 140628807952256 train.py:257] Step #12769: rate 0.000400, accuracy 71.0%, cross entropy 0.742010
# DEBUG:tensorflow:Step #12770: rate 0.000400, accuracy 81.0%, cross entropy 0.599763
# I0525 21:42:01.891195 140628807952256 train.py:257] Step #12770: rate 0.000400, accuracy 81.0%, cross entropy 0.599763
# DEBUG:tensorflow:Step #12771: rate 0.000400, accuracy 75.0%, cross entropy 0.589655
# I0525 21:42:02.237131 140628807952256 train.py:257] Step #12771: rate 0.000400, accuracy 75.0%, cross entropy 0.589655
# DEBUG:tensorflow:Step #12772: rate 0.000400, accuracy 78.0%, cross entropy 0.599582
# I0525 21:42:02.594986 140628807952256 train.py:257] Step #12772: rate 0.000400, accuracy 78.0%, cross entropy 0.599582
# DEBUG:tensorflow:Step #12773: rate 0.000400, accuracy 83.0%, cross entropy 0.516922
# I0525 21:42:02.936496 140628807952256 train.py:257] Step #12773: rate 0.000400, accuracy 83.0%, cross entropy 0.516922
# DEBUG:tensorflow:Step #12774: rate 0.000400, accuracy 88.0%, cross entropy 0.468968
# I0525 21:42:03.278818 140628807952256 train.py:257] Step #12774: rate 0.000400, accuracy 88.0%, cross entropy 0.468968
# DEBUG:tensorflow:Step #12775: rate 0.000400, accuracy 82.0%, cross entropy 0.530833
# I0525 21:42:03.621301 140628807952256 train.py:257] Step #12775: rate 0.000400, accuracy 82.0%, cross entropy 0.530833
# ...
# I0525 21:54:56.221428 140628807952256 train.py:257] Step #14930: rate 0.000100, accuracy 85.0%, cross entropy 0.487212
# DEBUG:tensorflow:Step #14931: rate 0.000100, accuracy 82.0%, cross entropy 0.534999
# I0525 21:54:56.552970 140628807952256 train.py:257] Step #14931: rate 0.000100, accuracy 82.0%, cross entropy 0.534999
# DEBUG:tensorflow:Step #14932: rate 0.000100, accuracy 79.0%, cross entropy 0.511580
# I0525 21:54:56.892651 140628807952256 train.py:257] Step #14932: rate 0.000100, accuracy 79.0%, cross entropy 0.511580
# DEBUG:tensorflow:Step #14933: rate 0.000100, accuracy 83.0%, cross entropy 0.623318
# I0525 21:54:57.223173 140628807952256 train.py:257] Step #14933: rate 0.000100, accuracy 83.0%, cross entropy 0.623318
# DEBUG:tensorflow:Step #14934: rate 0.000100, accuracy 83.0%, cross entropy 0.580848
# I0525 21:54:57.559847 140628807952256 train.py:257] Step #14934: rate 0.000100, accuracy 83.0%, cross entropy 0.580848
# DEBUG:tensorflow:Step #14935: rate 0.000100, accuracy 90.0%, cross entropy 0.403906
# I0525 21:54:57.902691 140628807952256 train.py:257] Step #14935: rate 0.000100, accuracy 90.0%, cross entropy 0.403906
# DEBUG:tensorflow:Step #14936: rate 0.000100, accuracy 79.0%, cross entropy 0.539935
# I0525 21:54:58.259384 140628807952256 train.py:257] Step #14936: rate 0.000100, accuracy 79.0%, cross entropy 0.539935
# DEBUG:tensorflow:Step #14937: rate 0.000100, accuracy 79.0%, cross entropy 0.549118
# I0525 21:54:58.625187 140628807952256 train.py:257] Step #14937: rate 0.000100, accuracy 79.0%, cross entropy 0.549118
# DEBUG:tensorflow:Step #14938: rate 0.000100, accuracy 81.0%, cross entropy 0.470523
# I0525 21:54:58.962863 140628807952256 train.py:257] Step #14938: rate 0.000100, accuracy 81.0%, cross entropy 0.470523
# DEBUG:tensorflow:Step #14939: rate 0.000100, accuracy 85.0%, cross entropy 0.458390
# I0525 21:54:59.310952 140628807952256 train.py:257] Step #14939: rate 0.000100, accuracy 85.0%, cross entropy 0.458390
# DEBUG:tensorflow:Step #14940: rate 0.000100, accuracy 88.0%, cross entropy 0.505722
# I0525 21:54:59.656103 140628807952256 train.py:257] Step #14940: rate 0.000100, accuracy 88.0%, cross entropy 0.505722
# DEBUG:tensorflow:Step #14941: rate 0.000100, accuracy 84.0%, cross entropy 0.564636
# I0525 21:54:59.983576 140628807952256 train.py:257] Step #14941: rate 0.000100, accuracy 84.0%, cross entropy 0.564636
# DEBUG:tensorflow:Step #14942: rate 0.000100, accuracy 72.0%, cross entropy 0.755420
# I0525 21:55:00.309888 140628807952256 train.py:257] Step #14942: rate 0.000100, accuracy 72.0%, cross entropy 0.755420
# DEBUG:tensorflow:Step #14943: rate 0.000100, accuracy 84.0%, cross entropy 0.473399
# I0525 21:55:00.649647 140628807952256 train.py:257] Step #14943: rate 0.000100, accuracy 84.0%, cross entropy 0.473399
# DEBUG:tensorflow:Step #14944: rate 0.000100, accuracy 84.0%, cross entropy 0.619471
# I0525 21:55:01.077775 140628807952256 train.py:257] Step #14944: rate 0.000100, accuracy 84.0%, cross entropy 0.619471
# DEBUG:tensorflow:Step #14945: rate 0.000100, accuracy 82.0%, cross entropy 0.455478
# I0525 21:55:01.594704 140628807952256 train.py:257] Step #14945: rate 0.000100, accuracy 82.0%, cross entropy 0.455478
# DEBUG:tensorflow:Step #14946: rate 0.000100, accuracy 82.0%, cross entropy 0.501413
# I0525 21:55:01.934934 140628807952256 train.py:257] Step #14946: rate 0.000100, accuracy 82.0%, cross entropy 0.501413
# DEBUG:tensorflow:Step #14947: rate 0.000100, accuracy 83.0%, cross entropy 0.505027
# I0525 21:55:02.262861 140628807952256 train.py:257] Step #14947: rate 0.000100, accuracy 83.0%, cross entropy 0.505027
# DEBUG:tensorflow:Step #14948: rate 0.000100, accuracy 79.0%, cross entropy 0.520850
# I0525 21:55:02.596173 140628807952256 train.py:257] Step #14948: rate 0.000100, accuracy 79.0%, cross entropy 0.520850
# DEBUG:tensorflow:Step #14949: rate 0.000100, accuracy 82.0%, cross entropy 0.490152
# I0525 21:55:02.930332 140628807952256 train.py:257] Step #14949: rate 0.000100, accuracy 82.0%, cross entropy 0.490152
# DEBUG:tensorflow:Step #14950: rate 0.000100, accuracy 84.0%, cross entropy 0.534059
# I0525 21:55:03.266953 140628807952256 train.py:257] Step #14950: rate 0.000100, accuracy 84.0%, cross entropy 0.534059
# DEBUG:tensorflow:Step #14951: rate 0.000100, accuracy 78.0%, cross entropy 0.663624
# I0525 21:55:03.603785 140628807952256 train.py:257] Step #14951: rate 0.000100, accuracy 78.0%, cross entropy 0.663624
# DEBUG:tensorflow:Step #14952: rate 0.000100, accuracy 79.0%, cross entropy 0.650562
# I0525 21:55:03.945217 140628807952256 train.py:257] Step #14952: rate 0.000100, accuracy 79.0%, cross entropy 0.650562
# DEBUG:tensorflow:Step #14953: rate 0.000100, accuracy 81.0%, cross entropy 0.459501
# I0525 21:55:04.274708 140628807952256 train.py:257] Step #14953: rate 0.000100, accuracy 81.0%, cross entropy 0.459501
# DEBUG:tensorflow:Step #14954: rate 0.000100, accuracy 81.0%, cross entropy 0.479573
# I0525 21:55:04.604377 140628807952256 train.py:257] Step #14954: rate 0.000100, accuracy 81.0%, cross entropy 0.479573
# DEBUG:tensorflow:Step #14955: rate 0.000100, accuracy 85.0%, cross entropy 0.543624
# I0525 21:55:04.979216 140628807952256 train.py:257] Step #14955: rate 0.000100, accuracy 85.0%, cross entropy 0.543624
# DEBUG:tensorflow:Step #14956: rate 0.000100, accuracy 79.0%, cross entropy 0.773652
# I0525 21:55:05.309643 140628807952256 train.py:257] Step #14956: rate 0.000100, accuracy 79.0%, cross entropy 0.773652
# DEBUG:tensorflow:Step #14957: rate 0.000100, accuracy 80.0%, cross entropy 0.553503
# I0525 21:55:05.641362 140628807952256 train.py:257] Step #14957: rate 0.000100, accuracy 80.0%, cross entropy 0.553503
# DEBUG:tensorflow:Step #14958: rate 0.000100, accuracy 80.0%, cross entropy 0.554141
# I0525 21:55:05.983831 140628807952256 train.py:257] Step #14958: rate 0.000100, accuracy 80.0%, cross entropy 0.554141
# DEBUG:tensorflow:Step #14959: rate 0.000100, accuracy 82.0%, cross entropy 0.557389
# I0525 21:55:06.315785 140628807952256 train.py:257] Step #14959: rate 0.000100, accuracy 82.0%, cross entropy 0.557389
# DEBUG:tensorflow:Step #14960: rate 0.000100, accuracy 85.0%, cross entropy 0.398379
# I0525 21:55:06.681257 140628807952256 train.py:257] Step #14960: rate 0.000100, accuracy 85.0%, cross entropy 0.398379
# DEBUG:tensorflow:Step #14961: rate 0.000100, accuracy 80.0%, cross entropy 0.600644
# I0525 21:55:07.189481 140628807952256 train.py:257] Step #14961: rate 0.000100, accuracy 80.0%, cross entropy 0.600644
# DEBUG:tensorflow:Step #14962: rate 0.000100, accuracy 81.0%, cross entropy 0.516496
# I0525 21:55:07.589618 140628807952256 train.py:257] Step #14962: rate 0.000100, accuracy 81.0%, cross entropy 0.516496
# DEBUG:tensorflow:Step #14963: rate 0.000100, accuracy 78.0%, cross entropy 0.612658
# I0525 21:55:07.929148 140628807952256 train.py:257] Step #14963: rate 0.000100, accuracy 78.0%, cross entropy 0.612658
# DEBUG:tensorflow:Step #14964: rate 0.000100, accuracy 83.0%, cross entropy 0.513139
# I0525 21:55:08.266449 140628807952256 train.py:257] Step #14964: rate 0.000100, accuracy 83.0%, cross entropy 0.513139
# DEBUG:tensorflow:Step #14965: rate 0.000100, accuracy 79.0%, cross entropy 0.533553
# I0525 21:55:08.599476 140628807952256 train.py:257] Step #14965: rate 0.000100, accuracy 79.0%, cross entropy 0.533553
# DEBUG:tensorflow:Step #14966: rate 0.000100, accuracy 84.0%, cross entropy 0.487201
# I0525 21:55:08.944920 140628807952256 train.py:257] Step #14966: rate 0.000100, accuracy 84.0%, cross entropy 0.487201
# DEBUG:tensorflow:Step #14967: rate 0.000100, accuracy 79.0%, cross entropy 0.714109
# I0525 21:55:09.279689 140628807952256 train.py:257] Step #14967: rate 0.000100, accuracy 79.0%, cross entropy 0.714109
# DEBUG:tensorflow:Step #14968: rate 0.000100, accuracy 76.0%, cross entropy 0.554805
# I0525 21:55:09.628977 140628807952256 train.py:257] Step #14968: rate 0.000100, accuracy 76.0%, cross entropy 0.554805
# DEBUG:tensorflow:Step #14969: rate 0.000100, accuracy 83.0%, cross entropy 0.507657
# I0525 21:55:09.978288 140628807952256 train.py:257] Step #14969: rate 0.000100, accuracy 83.0%, cross entropy 0.507657
# DEBUG:tensorflow:Step #14970: rate 0.000100, accuracy 78.0%, cross entropy 0.602729
# I0525 21:55:10.313951 140628807952256 train.py:257] Step #14970: rate 0.000100, accuracy 78.0%, cross entropy 0.602729
# DEBUG:tensorflow:Step #14971: rate 0.000100, accuracy 84.0%, cross entropy 0.556932
# I0525 21:55:10.646933 140628807952256 train.py:257] Step #14971: rate 0.000100, accuracy 84.0%, cross entropy 0.556932
# DEBUG:tensorflow:Step #14972: rate 0.000100, accuracy 88.0%, cross entropy 0.496544
# I0525 21:55:10.991509 140628807952256 train.py:257] Step #14972: rate 0.000100, accuracy 88.0%, cross entropy 0.496544
# DEBUG:tensorflow:Step #14973: rate 0.000100, accuracy 77.0%, cross entropy 0.709326
# I0525 21:55:11.325499 140628807952256 train.py:257] Step #14973: rate 0.000100, accuracy 77.0%, cross entropy 0.709326
# DEBUG:tensorflow:Step #14974: rate 0.000100, accuracy 72.0%, cross entropy 0.601350
# I0525 21:55:11.661746 140628807952256 train.py:257] Step #14974: rate 0.000100, accuracy 72.0%, cross entropy 0.601350
# DEBUG:tensorflow:Step #14975: rate 0.000100, accuracy 84.0%, cross entropy 0.441286
# I0525 21:55:12.039875 140628807952256 train.py:257] Step #14975: rate 0.000100, accuracy 84.0%, cross entropy 0.441286
# DEBUG:tensorflow:Step #14976: rate 0.000100, accuracy 80.0%, cross entropy 0.546793
# I0525 21:55:12.373608 140628807952256 train.py:257] Step #14976: rate 0.000100, accuracy 80.0%, cross entropy 0.546793
# DEBUG:tensorflow:Step #14977: rate 0.000100, accuracy 75.0%, cross entropy 0.594742
# I0525 21:55:12.823589 140628807952256 train.py:257] Step #14977: rate 0.000100, accuracy 75.0%, cross entropy 0.594742
# DEBUG:tensorflow:Step #14978: rate 0.000100, accuracy 84.0%, cross entropy 0.484769
# I0525 21:55:13.311751 140628807952256 train.py:257] Step #14978: rate 0.000100, accuracy 84.0%, cross entropy 0.484769
# DEBUG:tensorflow:Step #14979: rate 0.000100, accuracy 80.0%, cross entropy 0.559726
# I0525 21:55:13.646867 140628807952256 train.py:257] Step #14979: rate 0.000100, accuracy 80.0%, cross entropy 0.559726
# DEBUG:tensorflow:Step #14980: rate 0.000100, accuracy 83.0%, cross entropy 0.374695
# I0525 21:55:13.979542 140628807952256 train.py:257] Step #14980: rate 0.000100, accuracy 83.0%, cross entropy 0.374695
# DEBUG:tensorflow:Step #14981: rate 0.000100, accuracy 75.0%, cross entropy 0.644149
# I0525 21:55:14.314893 140628807952256 train.py:257] Step #14981: rate 0.000100, accuracy 75.0%, cross entropy 0.644149
# DEBUG:tensorflow:Step #14982: rate 0.000100, accuracy 81.0%, cross entropy 0.566593
# I0525 21:55:14.645394 140628807952256 train.py:257] Step #14982: rate 0.000100, accuracy 81.0%, cross entropy 0.566593
# DEBUG:tensorflow:Step #14983: rate 0.000100, accuracy 86.0%, cross entropy 0.399260
# I0525 21:55:14.984992 140628807952256 train.py:257] Step #14983: rate 0.000100, accuracy 86.0%, cross entropy 0.399260
# DEBUG:tensorflow:Step #14984: rate 0.000100, accuracy 83.0%, cross entropy 0.433171
# I0525 21:55:15.319263 140628807952256 train.py:257] Step #14984: rate 0.000100, accuracy 83.0%, cross entropy 0.433171
# DEBUG:tensorflow:Step #14985: rate 0.000100, accuracy 85.0%, cross entropy 0.558057
# I0525 21:55:15.650346 140628807952256 train.py:257] Step #14985: rate 0.000100, accuracy 85.0%, cross entropy 0.558057
# DEBUG:tensorflow:Step #14986: rate 0.000100, accuracy 83.0%, cross entropy 0.588578
# I0525 21:55:15.989351 140628807952256 train.py:257] Step #14986: rate 0.000100, accuracy 83.0%, cross entropy 0.588578
# DEBUG:tensorflow:Step #14987: rate 0.000100, accuracy 81.0%, cross entropy 0.541957
# I0525 21:55:16.338360 140628807952256 train.py:257] Step #14987: rate 0.000100, accuracy 81.0%, cross entropy 0.541957
# DEBUG:tensorflow:Step #14988: rate 0.000100, accuracy 83.0%, cross entropy 0.509050
# I0525 21:55:16.681668 140628807952256 train.py:257] Step #14988: rate 0.000100, accuracy 83.0%, cross entropy 0.509050
# DEBUG:tensorflow:Step #14989: rate 0.000100, accuracy 86.0%, cross entropy 0.472863
# I0525 21:55:17.022244 140628807952256 train.py:257] Step #14989: rate 0.000100, accuracy 86.0%, cross entropy 0.472863
# DEBUG:tensorflow:Step #14990: rate 0.000100, accuracy 72.0%, cross entropy 0.687334
# I0525 21:55:17.349769 140628807952256 train.py:257] Step #14990: rate 0.000100, accuracy 72.0%, cross entropy 0.687334
# DEBUG:tensorflow:Step #14991: rate 0.000100, accuracy 88.0%, cross entropy 0.443233
# I0525 21:55:17.684173 140628807952256 train.py:257] Step #14991: rate 0.000100, accuracy 88.0%, cross entropy 0.443233
# DEBUG:tensorflow:Step #14992: rate 0.000100, accuracy 82.0%, cross entropy 0.536536
# I0525 21:55:18.023937 140628807952256 train.py:257] Step #14992: rate 0.000100, accuracy 82.0%, cross entropy 0.536536
# DEBUG:tensorflow:Step #14993: rate 0.000100, accuracy 82.0%, cross entropy 0.532100
# I0525 21:55:18.459464 140628807952256 train.py:257] Step #14993: rate 0.000100, accuracy 82.0%, cross entropy 0.532100
# DEBUG:tensorflow:Step #14994: rate 0.000100, accuracy 84.0%, cross entropy 0.448554
# I0525 21:55:19.009142 140628807952256 train.py:257] Step #14994: rate 0.000100, accuracy 84.0%, cross entropy 0.448554
# DEBUG:tensorflow:Step #14995: rate 0.000100, accuracy 77.0%, cross entropy 0.674521
# I0525 21:55:19.382227 140628807952256 train.py:257] Step #14995: rate 0.000100, accuracy 77.0%, cross entropy 0.674521
# DEBUG:tensorflow:Step #14996: rate 0.000100, accuracy 76.0%, cross entropy 0.647860
# I0525 21:55:19.739520 140628807952256 train.py:257] Step #14996: rate 0.000100, accuracy 76.0%, cross entropy 0.647860
# DEBUG:tensorflow:Step #14997: rate 0.000100, accuracy 81.0%, cross entropy 0.563731
# I0525 21:55:20.089279 140628807952256 train.py:257] Step #14997: rate 0.000100, accuracy 81.0%, cross entropy 0.563731
# DEBUG:tensorflow:Step #14998: rate 0.000100, accuracy 81.0%, cross entropy 0.460647
# I0525 21:55:20.416294 140628807952256 train.py:257] Step #14998: rate 0.000100, accuracy 81.0%, cross entropy 0.460647
# DEBUG:tensorflow:Step #14999: rate 0.000100, accuracy 81.0%, cross entropy 0.562658
# I0525 21:55:20.752203 140628807952256 train.py:257] Step #14999: rate 0.000100, accuracy 81.0%, cross entropy 0.562658
# DEBUG:tensorflow:Step #15000: rate 0.000100, accuracy 83.0%, cross entropy 0.457545
# I0525 21:55:21.092480 140628807952256 train.py:257] Step #15000: rate 0.000100, accuracy 83.0%, cross entropy 0.457545
# INFO:tensorflow:Step #15000: rate 0.000100, accuracy 83.0%, cross entropy 0.457545
# I0525 21:55:21.092699 140628807952256 train.py:263] Step #15000: rate 0.000100, accuracy 83.0%, cross entropy 0.457545
# INFO:tensorflow:Confusion Matrix:
#  [[225   2   1   0   2   0]
#  [  0 103  30  38  30  29]
#  [  3   9 332   2   3   1]
#  [  2  30  20 312   2   6]
#  [  1   9  13   3 319   7]
#  [  2   8   3   1  15 334]]
# I0525 21:55:27.316007 140628807952256 train.py:287] Confusion Matrix:
#  [[225   2   1   0   2   0]
#  [  0 103  30  38  30  29]
#  [  3   9 332   2   3   1]
#  [  2  30  20 312   2   6]
#  [  1   9  13   3 319   7]
#  [  2   8   3   1  15 334]]
# INFO:tensorflow:Step 15000: Validation accuracy = 85.7% (N=1897)
# I0525 21:55:27.316310 140628807952256 train.py:289] Step 15000: Validation accuracy = 85.7% (N=1897)
# INFO:tensorflow:Saving to "train/tiny_conv.ckpt-15000"
# I0525 21:55:27.316419 140628807952256 train.py:297] Saving to "train/tiny_conv.ckpt-15000"
# INFO:tensorflow:set_size=2141
# I0525 21:55:27.339840 140628807952256 train.py:301] set_size=2141
# WARNING:tensorflow:Confusion Matrix:
#  [[256   3   1   0   0   0]
#  [  3 114  29  39  33  42]
#  [  1   7 382  10   9   2]
#  [  3  37  21 328  12   1]
#  [  1  16  10   9 369   7]
#  [  3  20   4   5  12 352]]
# W0525 21:55:37.677350 140628807952256 train.py:320] Confusion Matrix:
#  [[256   3   1   0   0   0]
#  [  3 114  29  39  33  42]
#  [  1   7 382  10   9   2]
#  [  3  37  21 328  12   1]
#  [  1  16  10   9 369   7]
#  [  3  20   4   5  12 352]]
# WARNING:tensorflow:Final test accuracy = 84.1% (N=2141)
# W0525 21:55:37.677548 140628807952256 train.py:322] Final test accuracy = 84.1% (N=2141)

# %% [markdown]
# # Generating your Model
# Just like with the pre-trained model we will now take the final checkpoint and convert it into a quantized TensorFlow Lite model.

# %% [markdown]
# ### Generate a TensorFlow Model for Inference
#
# Combine relevant training results (graph, weights, etc) into a single file for inference. This process is known as freezing a model and the resulting model is known as a frozen model/graph, as it cannot be further re-trained after this process.

# %%
# !rm -rf {SAVED_MODEL}
# !python tensorflow/tensorflow/examples/speech_commands/freeze.py \
--wanted_words=$WANTED_WORDS \
--window_stride_ms=$WINDOW_STRIDE \
--preprocess=$PREPROCESS \
--model_architecture=$MODEL_ARCHITECTURE \
--start_checkpoint=$TRAIN_DIR$MODEL_ARCHITECTURE'.ckpt-'{TOTAL_STEPS} \
--save_format=saved_model \
--output_file={SAVED_MODEL}
# Out:
# 2021-05-25 21:55:59.652589: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2021-05-25 21:55:59.652836: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x563da50e0a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-25 21:55:59.652870: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-05-25 21:55:59.656211: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-05-25 21:55:59.886128: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 21:55:59.886952: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x563da50e1b80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-05-25 21:55:59.886987: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2021-05-25 21:55:59.887170: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 21:55:59.887846: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-05-25 21:55:59.890535: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-25 21:55:59.900305: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-05-25 21:55:59.906058: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-05-25 21:55:59.911832: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-05-25 21:55:59.921316: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-05-25 21:55:59.924042: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-05-25 21:55:59.936155: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-05-25 21:55:59.936280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 21:55:59.936884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 21:55:59.937388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-05-25 21:55:59.937437: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-25 21:55:59.938428: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-25 21:55:59.938452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-05-25 21:55:59.938469: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-05-25 21:55:59.938578: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 21:55:59.939157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 21:55:59.939720: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from train/tiny_conv.ckpt-15000
# I0525 21:55:59.977025 140388085671808 saver.py:1284] Restoring parameters from train/tiny_conv.ckpt-15000
# WARNING:tensorflow:From tensorflow/tensorflow/examples/speech_commands/freeze.py:235: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W0525 21:56:00.348525 140388085671808 deprecation.py:323] From tensorflow/tensorflow/examples/speech_commands/freeze.py:235: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W0525 21:56:00.348782 140388085671808 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 4 variables.
# I0525 21:56:00.353259 140388085671808 graph_util_impl.py:334] Froze 4 variables.
# INFO:tensorflow:Converted 4 variables to const ops.
# I0525 21:56:00.354280 140388085671808 graph_util_impl.py:394] Converted 4 variables to const ops.
# WARNING:tensorflow:From tensorflow/tensorflow/examples/speech_commands/freeze.py:188: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0525 21:56:00.356476 140388085671808 deprecation.py:323] From tensorflow/tensorflow/examples/speech_commands/freeze.py:188: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:No assets to save.
# I0525 21:56:00.356998 140388085671808 builder_impl.py:640] No assets to save.
# INFO:tensorflow:No assets to write.
# I0525 21:56:00.357113 140388085671808 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: models/saved_model/saved_model.pb
# I0525 21:56:00.384566 140388085671808 builder_impl.py:425] SavedModel written to: models/saved_model/saved_model.pb

# %% [markdown]
# ### Generate a TensorFlow Lite Model
#
# Convert the frozen graph into a TensorFlow Lite model, which is fully quantized for use with embedded devices.
#
# The following cell will also print the model size, which will be under 20 kilobytes.
#
# We download the dataset to use as a representative dataset for more thoughtful post training quantization.

# %%
model_settings = models.prepare_model_settings(
    len(input_data.prepare_words_list(WANTED_WORDS.split(','))),
    SAMPLE_RATE, CLIP_DURATION_MS, WINDOW_SIZE_MS,
    WINDOW_STRIDE, FEATURE_BIN_COUNT, PREPROCESS)
audio_processor = input_data.AudioProcessor(
    DATA_URL, DATASET_DIR,
    SILENT_PERCENTAGE, UNKNOWN_PERCENTAGE,
    WANTED_WORDS.split(','), VALIDATION_PERCENTAGE,
    TESTING_PERCENTAGE, model_settings, LOGS_DIR)

# %%
with tf.Session() as sess:
  # with tf.compat.v1.Session() as sess: #replaces the above line for use with TF2.x
  float_converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL)
  float_tflite_model = float_converter.convert()
  float_tflite_model_size = open(FLOAT_MODEL_TFLITE, "wb").write(float_tflite_model)
  print("Float model is %d bytes" % float_tflite_model_size)

  converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL)
  converter.optimizations = [tf.lite.Optimize.DEFAULT]
  converter.inference_input_type = tf.lite.constants.INT8
  # converter.inference_input_type = tf.compat.v1.lite.constants.INT8 #replaces the above line for use with TF2.x   
  converter.inference_output_type = tf.lite.constants.INT8
  # converter.inference_output_type = tf.compat.v1.lite.constants.INT8 #replaces the above line for use with TF2.x
  def representative_dataset_gen():
    for i in range(100):
      data, _ = audio_processor.get_data(1, i*1, model_settings,
                                         BACKGROUND_FREQUENCY, 
                                         BACKGROUND_VOLUME_RANGE,
                                         TIME_SHIFT_MS,
                                         'testing',
                                         sess)
      flattened_data = np.array(data.flatten(), dtype=np.float32).reshape(FLATTENED_SPECTROGRAM_SHAPE)
      yield [flattened_data]
  converter.representative_dataset = representative_dataset_gen
  tflite_model = converter.convert()
  tflite_model_size = open(MODEL_TFLITE, "wb").write(tflite_model)
  print("Quantized model is %d bytes" % tflite_model_size)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/lite/python/convert_saved_model.py:60: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# INFO:tensorflow:Restoring parameters from models/saved_model/variables/variables
# INFO:tensorflow:The given SavedModel MetaGraphDef contains SignatureDefs with the following keys: {'serving_default'}
# INFO:tensorflow:input tensors info:
# INFO:tensorflow:Tensor's key in saved_model's tensor_map: input
# INFO:tensorflow: tensor name: Reshape_1:0, shape: (1, 1960), type: DT_FLOAT
# INFO:tensorflow:output tensors info:
# INFO:tensorflow:Tensor's key in saved_model's tensor_map: output
# INFO:tensorflow: tensor name: labels_softmax:0, shape: (1, 6), type: DT_FLOAT
# INFO:tensorflow:Restoring parameters from models/saved_model/variables/variables
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/lite/python/util.py:249: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 4 variables.
# INFO:tensorflow:Converted 4 variables to const ops.
# Float model is 100056 bytes
# INFO:tensorflow:Restoring parameters from models/saved_model/variables/variables
# INFO:tensorflow:The given SavedModel MetaGraphDef contains SignatureDefs with the following keys: {'serving_default'}
# INFO:tensorflow:input tensors info:
# INFO:tensorflow:Tensor's key in saved_model's tensor_map: input
# INFO:tensorflow: tensor name: Reshape_1:0, shape: (1, 1960), type: DT_FLOAT
# INFO:tensorflow:output tensors info:
# INFO:tensorflow:Tensor's key in saved_model's tensor_map: output
# INFO:tensorflow: tensor name: labels_softmax:0, shape: (1, 6), type: DT_FLOAT
# INFO:tensorflow:Restoring parameters from models/saved_model/variables/variables
# INFO:tensorflow:Froze 4 variables.
# INFO:tensorflow:Converted 4 variables to const ops.
# Quantized model is 26720 bytes

# %% [markdown]
# ### Testing the accuracy after Quantization
#
# Verify that the model we've exported is still accurate, using the TF Lite Python API and our test set.

# %%
# Helper function to run inference
def run_tflite_inference_testSet(tflite_model_path, model_type="Float"):
  #
  # Load test data
  #
  np.random.seed(0) # set random seed for reproducible test results.
  with tf.Session() as sess:
  # with tf.compat.v1.Session() as sess: #replaces the above line for use with TF2.x
    test_data, test_labels = audio_processor.get_data(
        -1, 0, model_settings, BACKGROUND_FREQUENCY, BACKGROUND_VOLUME_RANGE,
        TIME_SHIFT_MS, 'testing', sess)
  test_data = np.expand_dims(test_data, axis=1).astype(np.float32)

  #
  # Initialize the interpreter
  #
  interpreter = tf.lite.Interpreter(tflite_model_path)
  interpreter.allocate_tensors()
  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]
  
  #
  # For quantized models, manually quantize the input data from float to integer
  #
  if model_type == "Quantized":
    input_scale, input_zero_point = input_details["quantization"]
    test_data = test_data / input_scale + input_zero_point
    test_data = test_data.astype(input_details["dtype"])

  #
  # Evaluate the predictions
  #
  correct_predictions = 0
  for i in range(len(test_data)):
    interpreter.set_tensor(input_details["index"], test_data[i])
    interpreter.invoke()
    output = interpreter.get_tensor(output_details["index"])[0]
    top_prediction = output.argmax()
    correct_predictions += (top_prediction == test_labels[i])

  print('%s model accuracy is %f%% (Number of test samples=%d)' % (
      model_type, (correct_predictions * 100) / len(test_data), len(test_data)))

# %%
# Compute float model accuracy
run_tflite_inference_testSet(FLOAT_MODEL_TFLITE)

# Compute quantized model accuracy
run_tflite_inference_testSet(MODEL_TFLITE, model_type='Quantized')
# Out:
# Float model accuracy is 83.886035% (Number of test samples=2141)
# Quantized model accuracy is 83.699206% (Number of test samples=2141)

# %% [markdown]
# # Testing the model with your own data!
# Now comes the fun part. It's time to test your model with your own realworld data. We'll proceed in the same way we tested the pre-trained model. Have fun!

# %% [markdown]
# ### Importing packages

# %%
# !pip install ffmpeg-python &> 0
from IPython.display import HTML, Audio
from google.colab.output import eval_js
from base64 import b64decode
import numpy as np
from scipy.io.wavfile import read as wav_read
import io
import ffmpeg
# !pip install librosa
import librosa
import scipy.io.wavfile
# !git clone https://github.com/petewarden/extract_loudest_section.git
# !make -C extract_loudest_section/
print("Packages Imported, Extract_Loudest_Section Built")

# %% [markdown]
# ### Define the helper function to run inference

# %%
# Helper function to run inference (on a single input this time)
# Note: this also includes additional manual pre-processing
TF_SESS = tf.compat.v1.InteractiveSession()
def run_tflite_inference_singleFile(tflite_model_path, custom_audio, sr_custom_audio, model_type="Float"):
  #
  # Preprocess the sample to get the features we pass to the model
  #
  # First re-sample to the needed rate (and convert to mono if needed)
  custom_audio_resampled = librosa.resample(librosa.to_mono(np.float64(custom_audio)), sr_custom_audio, SAMPLE_RATE)
  # Then extract the loudest one second
  scipy.io.wavfile.write('custom_audio.wav', SAMPLE_RATE, np.int16(custom_audio_resampled))
  # !/tmp/extract_loudest_section/gen/bin/extract_loudest_section custom_audio.wav ./trimmed
  # Finally pass it through the TFLiteMicro preprocessor to produce the 
  # spectrogram/MFCC input that the model expects
  custom_model_settings = models.prepare_model_settings(
      0, SAMPLE_RATE, CLIP_DURATION_MS, WINDOW_SIZE_MS,
      WINDOW_STRIDE, FEATURE_BIN_COUNT, PREPROCESS)
  custom_audio_processor = input_data.AudioProcessor(None, None, 0, 0, '', 0, 0,
                                                    model_settings, None)
  custom_audio_preprocessed = custom_audio_processor.get_features_for_wav(
                                        'trimmed/custom_audio.wav', model_settings, TF_SESS)
  # Reshape the output into a 1,1960 matrix as that is what the model expects
  custom_audio_input = custom_audio_preprocessed[0].flatten()
  test_data = np.reshape(custom_audio_input,(1,len(custom_audio_input)))

  #
  # Initialize the interpreter
  #
  interpreter = tf.lite.Interpreter(tflite_model_path)
  interpreter.allocate_tensors()
  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  #
  # For quantized models, manually quantize the input data from float to integer
  #
  if model_type == "Quantized":
    input_scale, input_zero_point = input_details["quantization"]
    test_data = test_data / input_scale + input_zero_point
    test_data = test_data.astype(input_details["dtype"])

  #
  # Run the interpreter
  #
  interpreter.set_tensor(input_details["index"], test_data)
  interpreter.invoke()
  output = interpreter.get_tensor(output_details["index"])[0]
  top_prediction = output.argmax()

  #
  # Translate the output
  #
  top_prediction_str = ''
  if top_prediction >= 2:
    top_prediction_str = WANTED_WORDS.split(',')[top_prediction-2]
  elif top_prediction == 0:
    top_prediction_str = 'silence'
  else:
    top_prediction_str = 'unknown'

  print('%s model guessed the value to be %s' % (model_type, top_prediction_str))

# %% [markdown]
# ### Define the audio importing function
# Adapted from: https://ricardodeazambuja.com/deep_learning/2019/03/09/audio_and_video_google_colab/ and https://colab.research.google.com/drive/1Z6VIRZ_sX314hyev3Gm5gBqvm1wQVo-a#scrollTo=RtMcXr3o6gxN

# %%
AUDIO_HTML = """
<script>
var my_div = document.createElement("DIV");
var my_p = document.createElement("P");
var my_btn = document.createElement("BUTTON");
var t = document.createTextNode("Press to start recording");

my_btn.appendChild(t);
//my_p.appendChild(my_btn);
my_div.appendChild(my_btn);
document.body.appendChild(my_div);

var base64data = 0;
var reader;
var recorder, gumStream;
var recordButton = my_btn;

var handleSuccess = function(stream) {
  gumStream = stream;
  var options = {
    //bitsPerSecond: 8000, //chrome seems to ignore, always 48k
    mimeType : 'audio/webm;codecs=opus'
    //mimeType : 'audio/webm;codecs=pcm'
  };            
  //recorder = new MediaRecorder(stream, options);
  recorder = new MediaRecorder(stream);
  recorder.ondataavailable = function(e) {            
    var url = URL.createObjectURL(e.data);
    var preview = document.createElement('audio');
    preview.controls = true;
    preview.src = url;
    document.body.appendChild(preview);

    reader = new FileReader();
    reader.readAsDataURL(e.data); 
    reader.onloadend = function() {
      base64data = reader.result;
      //console.log("Inside FileReader:" + base64data);
    }
  };
  recorder.start();
  };

recordButton.innerText = "Recording... press to stop";

navigator.mediaDevices.getUserMedia({audio: true}).then(handleSuccess);


function toggleRecording() {
  if (recorder && recorder.state == "recording") {
      recorder.stop();
      gumStream.getAudioTracks()[0].stop();
      recordButton.innerText = "Saving the recording... pls wait!"
  }
}

// https://stackoverflow.com/a/951057
function sleep(ms) {
  return new Promise(resolve => setTimeout(resolve, ms));
}

var data = new Promise(resolve=>{
//recordButton.addEventListener("click", toggleRecording);
recordButton.onclick = ()=>{
toggleRecording()

sleep(2000).then(() => {
  // wait 2000ms for the data to be available...
  // ideally this should use something like await...
  //console.log("Inside data:" + base64data)
  resolve(base64data.toString())

});

}
});
      
</script>
"""

def get_audio():
  display(HTML(AUDIO_HTML))
  data = eval_js("data")
  binary = b64decode(data.split(',')[1])
  
  process = (ffmpeg
    .input('pipe:0')
    .output('pipe:1', format='wav', ac='1')
    .run_async(pipe_stdin=True, pipe_stdout=True, pipe_stderr=True, quiet=True, overwrite_output=True)
  )
  output, err = process.communicate(input=binary)
  
  riff_chunk_size = len(output) - 8
  # Break up the chunk size into four bytes, held in b.
  q = riff_chunk_size
  b = []
  for i in range(4):
      q, r = divmod(q, 256)
      b.append(r)

  # Replace bytes 4:8 in proc.stdout with the actual size of the RIFF chunk.
  riff = output[:4] + bytes(b) + output[8:]

  sr, audio = wav_read(io.BytesIO(riff))

  return audio, sr
print("Chrome Audio Recorder Defined")

# %% [markdown]
# ### Record your own audio and test the model!
# After you run the record cell wait for the stop button to appear then start recording and then press the button to stop the recording once you have said the word!

# %%
custom_audio, sr_custom_audio = get_audio()
print("DONE")

# %%
# Then test the model
run_tflite_inference_singleFile(MODEL_TFLITE, custom_audio, sr_custom_audio, model_type="Quantized")
